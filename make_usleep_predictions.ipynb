# %%
import os


# GLOBALS
PREDICTIONS_DIR = "predictions"
CHANNELS = """"O1-M2"==EEG "O2-M1"==EEG "E1-M1"==EOG "E2-M1"==EOG"""
GROUPING = "EOG EEG"
NUM_GPUS = 0
LOG_DIR = "logs"
MODEL = "u-sleep:1.0"

# Helpers
set_log_path = lambda x: os.path.join(LOG_DIR, x.replace(".npy",".log"))
set_predictions = lambda x: os.path.join(PREDICTIONS_DIR,x) if PREDICTIONS_DIR not in x else x

def console_predict_one(input_file, output_file, data_per_prediction):

    cmd = (
            f"ut predict_one"
            f" -f {input_file}"
            f" -o {set_predictions(output_file)}"
            f" --channels {CHANNELS}"
            f" --auto_channel_grouping {GROUPING}"
            f" --model {MODEL}"
            f" --logging_out_path {set_log_path(output_file)}"
            f" --num_gpus {NUM_GPUS}"
            f" --data_per_prediction {data_per_prediction}"
            f" --no_argmax"
            f" --overwrite"
        )

    print(cmd)
    out = os.system(cmd)
    
    return "call failed..." if out > 0 else "call successful"

# %%
import glob
import os

files = glob.glob("edf_data\\*.edf")

prediction_rate = [1, 8, 16, 32]
samp_rate = 128

for hz in prediction_rate:
    data_per_prediction = int(samp_rate * (1/hz))
    for file in files:
        inp = file
        folder=f"predictions\\{hz}_hz"
        if not os.path.exists(folder):
            os.mkdir(folder)
        npy_file = file.split('\\')[-1].replace('.edf','.npy')
        out = f"{folder}\\{npy_file}"
        print(f"Predicting file {file} @ {hz} Hz")
        console_predict_one(input_file=inp, output_file=out, data_per_prediction=data_per_prediction)
# Out:
# Predicting file edf_data\0ncr.edf @ 1 Hz
# Predicting file edf_data\0pai.edf @ 1 Hz
# Predicting file edf_data\3J4W.edf @ 1 Hz
# Predicting file edf_data\3P0D.edf @ 1 Hz
# Predicting file edf_data\40kO.edf @ 1 Hz
# Predicting file edf_data\5bSg.edf @ 1 Hz
# Predicting file edf_data\6iwd.edf @ 1 Hz
# Predicting file edf_data\6JVj.edf @ 1 Hz
# Predicting file edf_data\9098.edf @ 1 Hz
# Predicting file edf_data\9JQY.edf @ 1 Hz
# Predicting file edf_data\Af8a.edf @ 1 Hz
# Predicting file edf_data\AsLD.edf @ 1 Hz
# Predicting file edf_data\AXbm.edf @ 1 Hz
# Predicting file edf_data\bkx9.edf @ 1 Hz
# Predicting file edf_data\BSvO.edf @ 1 Hz
# Predicting file edf_data\C1Wu.edf @ 1 Hz
# Predicting file edf_data\cblr.edf @ 1 Hz
# Predicting file edf_data\csxQ.edf @ 1 Hz
# Predicting file edf_data\d3ET.edf @ 1 Hz
# Predicting file edf_data\ddTG.edf @ 1 Hz
# Predicting file edf_data\DjrT.edf @ 1 Hz
# Predicting file edf_data\Dr51.edf @ 1 Hz
# Predicting file edf_data\DSfb.edf @ 1 Hz
# Predicting file edf_data\DYYI.edf @ 1 Hz
# Predicting file edf_data\EHED.edf @ 1 Hz
# Predicting file edf_data\EMcQ.edf @ 1 Hz
# Predicting file edf_data\EyTS.edf @ 1 Hz
# Predicting file edf_data\f8H5.edf @ 1 Hz
# Predicting file edf_data\fNe4.edf @ 1 Hz
# Predicting file edf_data\fT68.edf @ 1 Hz
# Predicting file edf_data\G7PJ.edf @ 1 Hz
# Predicting file edf_data\go56.edf @ 1 Hz
# Predicting file edf_data\hcml.edf @ 1 Hz
# Predicting file edf_data\hRMy.edf @ 1 Hz
# Predicting file edf_data\hT38.edf @ 1 Hz
# Predicting file edf_data\ibbz.edf @ 1 Hz
# Predicting file edf_data\IhpU.edf @ 1 Hz
# Predicting file edf_data\ipxV.edf @ 1 Hz
# Predicting file edf_data\iSqw.edf @ 1 Hz
# Predicting file edf_data\Ivfn.edf @ 1 Hz
# Predicting file edf_data\JCpz.edf @ 1 Hz
# Predicting file edf_data\kj2l.edf @ 1 Hz
# Predicting file edf_data\Kn9O.edf @ 1 Hz
# Predicting file edf_data\LR2s.edf @ 1 Hz
# Predicting file edf_data\mBks.edf @ 1 Hz
# Predicting file edf_data\MS6u.edf @ 1 Hz
# Predicting file edf_data\Msy4.edf @ 1 Hz
# Predicting file edf_data\muls.edf @ 1 Hz
# Predicting file edf_data\mZje.edf @ 1 Hz
# Predicting file edf_data\N1nM.edf @ 1 Hz
# Predicting file edf_data\Nzhl.edf @ 1 Hz
# Predicting file edf_data\oOMR.edf @ 1 Hz
# Predicting file edf_data\Otq3.edf @ 1 Hz
# Predicting file edf_data\pPpj.edf @ 1 Hz
# Predicting file edf_data\puoa.edf @ 1 Hz
# Predicting file edf_data\QDsa.edf @ 1 Hz
# Predicting file edf_data\R2f3.edf @ 1 Hz
# Predicting file edf_data\RfL0.edf @ 1 Hz
# Predicting file edf_data\RM1S.edf @ 1 Hz
# Predicting file edf_data\sNMf.edf @ 1 Hz
# Predicting file edf_data\SOZ3.edf @ 1 Hz
# Predicting file edf_data\svlu.edf @ 1 Hz
# Predicting file edf_data\tG6i.edf @ 1 Hz
# Predicting file edf_data\UsSz.edf @ 1 Hz
# Predicting file edf_data\UwK6.edf @ 1 Hz
# Predicting file edf_data\uXdB.edf @ 1 Hz
# Predicting file edf_data\X7s0.edf @ 1 Hz
# Predicting file edf_data\Xg1l.edf @ 1 Hz
# Predicting file edf_data\Xii6.edf @ 1 Hz
# Predicting file edf_data\Y4FK.edf @ 1 Hz
# Predicting file edf_data\y5We.edf @ 1 Hz
# Predicting file edf_data\YHLr.edf @ 1 Hz
# Predicting file edf_data\YOh8.edf @ 1 Hz
# Predicting file edf_data\zaca.edf @ 1 Hz
# Predicting file edf_data\Zpwh.edf @ 1 Hz
# Predicting file edf_data\ZYFG.edf @ 1 Hz
# Predicting file edf_data\0ncr.edf @ 8 Hz
# Predicting file edf_data\0pai.edf @ 8 Hz
# Predicting file edf_data\3J4W.edf @ 8 Hz
# Predicting file edf_data\3P0D.edf @ 8 Hz
# Predicting file edf_data\40kO.edf @ 8 Hz
# Predicting file edf_data\5bSg.edf @ 8 Hz
# Predicting file edf_data\6iwd.edf @ 8 Hz
# Predicting file edf_data\6JVj.edf @ 8 Hz
# Predicting file edf_data\9098.edf @ 8 Hz
# Predicting file edf_data\9JQY.edf @ 8 Hz
# Predicting file edf_data\Af8a.edf @ 8 Hz
# Predicting file edf_data\AsLD.edf @ 8 Hz
# Predicting file edf_data\AXbm.edf @ 8 Hz
# Predicting file edf_data\bkx9.edf @ 8 Hz
# Predicting file edf_data\BSvO.edf @ 8 Hz
# Predicting file edf_data\C1Wu.edf @ 8 Hz
# Predicting file edf_data\cblr.edf @ 8 Hz
# Predicting file edf_data\csxQ.edf @ 8 Hz
# Predicting file edf_data\d3ET.edf @ 8 Hz
# Predicting file edf_data\ddTG.edf @ 8 Hz
# Predicting file edf_data\DjrT.edf @ 8 Hz
# Predicting file edf_data\Dr51.edf @ 8 Hz
# Predicting file edf_data\DSfb.edf @ 8 Hz
# Predicting file edf_data\DYYI.edf @ 8 Hz
# Predicting file edf_data\EHED.edf @ 8 Hz
# Predicting file edf_data\EMcQ.edf @ 8 Hz
# Predicting file edf_data\EyTS.edf @ 8 Hz
# Predicting file edf_data\f8H5.edf @ 8 Hz
# Predicting file edf_data\fNe4.edf @ 8 Hz
# Predicting file edf_data\fT68.edf @ 8 Hz
# Predicting file edf_data\G7PJ.edf @ 8 Hz
# Predicting file edf_data\go56.edf @ 8 Hz
# Predicting file edf_data\hcml.edf @ 8 Hz
# Predicting file edf_data\hRMy.edf @ 8 Hz
# Predicting file edf_data\hT38.edf @ 8 Hz
# Predicting file edf_data\ibbz.edf @ 8 Hz
# Predicting file edf_data\IhpU.edf @ 8 Hz
# Predicting file edf_data\ipxV.edf @ 8 Hz
# Predicting file edf_data\iSqw.edf @ 8 Hz
# Predicting file edf_data\Ivfn.edf @ 8 Hz
# Predicting file edf_data\JCpz.edf @ 8 Hz
# Predicting file edf_data\kj2l.edf @ 8 Hz
# Predicting file edf_data\Kn9O.edf @ 8 Hz
# Predicting file edf_data\LR2s.edf @ 8 Hz
# Predicting file edf_data\mBks.edf @ 8 Hz
# Predicting file edf_data\MS6u.edf @ 8 Hz
# Predicting file edf_data\Msy4.edf @ 8 Hz
# Predicting file edf_data\muls.edf @ 8 Hz
# Predicting file edf_data\mZje.edf @ 8 Hz
# Predicting file edf_data\N1nM.edf @ 8 Hz
# Predicting file edf_data\Nzhl.edf @ 8 Hz
# Predicting file edf_data\oOMR.edf @ 8 Hz
# Predicting file edf_data\Otq3.edf @ 8 Hz
# Predicting file edf_data\pPpj.edf @ 8 Hz
# Predicting file edf_data\puoa.edf @ 8 Hz
# Predicting file edf_data\QDsa.edf @ 8 Hz
# Predicting file edf_data\R2f3.edf @ 8 Hz
# Predicting file edf_data\RfL0.edf @ 8 Hz
# Predicting file edf_data\RM1S.edf @ 8 Hz
# Predicting file edf_data\sNMf.edf @ 8 Hz
# Predicting file edf_data\SOZ3.edf @ 8 Hz
# Predicting file edf_data\svlu.edf @ 8 Hz
# Predicting file edf_data\tG6i.edf @ 8 Hz
# Predicting file edf_data\UsSz.edf @ 8 Hz
# Predicting file edf_data\UwK6.edf @ 8 Hz
# Predicting file edf_data\uXdB.edf @ 8 Hz
# Predicting file edf_data\X7s0.edf @ 8 Hz
# Predicting file edf_data\Xg1l.edf @ 8 Hz
# Predicting file edf_data\Xii6.edf @ 8 Hz
# Predicting file edf_data\Y4FK.edf @ 8 Hz
# Predicting file edf_data\y5We.edf @ 8 Hz
# Predicting file edf_data\YHLr.edf @ 8 Hz
# Predicting file edf_data\YOh8.edf @ 8 Hz
# Predicting file edf_data\zaca.edf @ 8 Hz
# Predicting file edf_data\Zpwh.edf @ 8 Hz
# Predicting file edf_data\ZYFG.edf @ 8 Hz
# Predicting file edf_data\0ncr.edf @ 16 Hz
# Predicting file edf_data\0pai.edf @ 16 Hz
# Predicting file edf_data\3J4W.edf @ 16 Hz
# Predicting file edf_data\3P0D.edf @ 16 Hz
# Predicting file edf_data\40kO.edf @ 16 Hz
# Predicting file edf_data\5bSg.edf @ 16 Hz
# Predicting file edf_data\6iwd.edf @ 16 Hz
# Predicting file edf_data\6JVj.edf @ 16 Hz
# Predicting file edf_data\9098.edf @ 16 Hz
# Predicting file edf_data\9JQY.edf @ 16 Hz
# Predicting file edf_data\Af8a.edf @ 16 Hz
# Predicting file edf_data\AsLD.edf @ 16 Hz
# Predicting file edf_data\AXbm.edf @ 16 Hz
# Predicting file edf_data\bkx9.edf @ 16 Hz
# Predicting file edf_data\BSvO.edf @ 16 Hz
# Predicting file edf_data\C1Wu.edf @ 16 Hz
# Predicting file edf_data\cblr.edf @ 16 Hz
# Predicting file edf_data\csxQ.edf @ 16 Hz
# Predicting file edf_data\d3ET.edf @ 16 Hz
# Predicting file edf_data\ddTG.edf @ 16 Hz
# Predicting file edf_data\DjrT.edf @ 16 Hz
# Predicting file edf_data\Dr51.edf @ 16 Hz
# Predicting file edf_data\DSfb.edf @ 16 Hz
# Predicting file edf_data\DYYI.edf @ 16 Hz
# Predicting file edf_data\EHED.edf @ 16 Hz
# Predicting file edf_data\EMcQ.edf @ 16 Hz
# Predicting file edf_data\EyTS.edf @ 16 Hz
# Predicting file edf_data\f8H5.edf @ 16 Hz
# Predicting file edf_data\fNe4.edf @ 16 Hz
# Predicting file edf_data\fT68.edf @ 16 Hz
# Predicting file edf_data\G7PJ.edf @ 16 Hz
# Predicting file edf_data\go56.edf @ 16 Hz
# Predicting file edf_data\hcml.edf @ 16 Hz
# Predicting file edf_data\hRMy.edf @ 16 Hz
# Predicting file edf_data\hT38.edf @ 16 Hz
# Predicting file edf_data\ibbz.edf @ 16 Hz
# Predicting file edf_data\IhpU.edf @ 16 Hz
# Predicting file edf_data\ipxV.edf @ 16 Hz
# Predicting file edf_data\iSqw.edf @ 16 Hz
# Predicting file edf_data\Ivfn.edf @ 16 Hz
# Predicting file edf_data\JCpz.edf @ 16 Hz
# Predicting file edf_data\kj2l.edf @ 16 Hz
# Predicting file edf_data\Kn9O.edf @ 16 Hz
# Predicting file edf_data\LR2s.edf @ 16 Hz
# Predicting file edf_data\mBks.edf @ 16 Hz
# Predicting file edf_data\MS6u.edf @ 16 Hz
# Predicting file edf_data\Msy4.edf @ 16 Hz
# Predicting file edf_data\muls.edf @ 16 Hz
# Predicting file edf_data\mZje.edf @ 16 Hz
# Predicting file edf_data\N1nM.edf @ 16 Hz
# Predicting file edf_data\Nzhl.edf @ 16 Hz
# Predicting file edf_data\oOMR.edf @ 16 Hz
# Predicting file edf_data\Otq3.edf @ 16 Hz
# Predicting file edf_data\pPpj.edf @ 16 Hz
# Predicting file edf_data\puoa.edf @ 16 Hz
# Predicting file edf_data\QDsa.edf @ 16 Hz
# Predicting file edf_data\R2f3.edf @ 16 Hz
# Predicting file edf_data\RfL0.edf @ 16 Hz
# Predicting file edf_data\RM1S.edf @ 16 Hz
# Predicting file edf_data\sNMf.edf @ 16 Hz
# Predicting file edf_data\SOZ3.edf @ 16 Hz
# Predicting file edf_data\svlu.edf @ 16 Hz
# Predicting file edf_data\tG6i.edf @ 16 Hz
# Predicting file edf_data\UsSz.edf @ 16 Hz
# Predicting file edf_data\UwK6.edf @ 16 Hz
# Predicting file edf_data\uXdB.edf @ 16 Hz
# Predicting file edf_data\X7s0.edf @ 16 Hz
# Predicting file edf_data\Xg1l.edf @ 16 Hz
# Predicting file edf_data\Xii6.edf @ 16 Hz
# Predicting file edf_data\Y4FK.edf @ 16 Hz
# Predicting file edf_data\y5We.edf @ 16 Hz
# Predicting file edf_data\YHLr.edf @ 16 Hz
# Predicting file edf_data\YOh8.edf @ 16 Hz
# Predicting file edf_data\zaca.edf @ 16 Hz
# Predicting file edf_data\Zpwh.edf @ 16 Hz
# Predicting file edf_data\ZYFG.edf @ 16 Hz
# Predicting file edf_data\0ncr.edf @ 32 Hz
# Predicting file edf_data\0pai.edf @ 32 Hz
# Predicting file edf_data\3J4W.edf @ 32 Hz
# Predicting file edf_data\3P0D.edf @ 32 Hz
# Predicting file edf_data\40kO.edf @ 32 Hz
# Predicting file edf_data\5bSg.edf @ 32 Hz
# Predicting file edf_data\6iwd.edf @ 32 Hz
# Predicting file edf_data\6JVj.edf @ 32 Hz
# Predicting file edf_data\9098.edf @ 32 Hz
# Predicting file edf_data\9JQY.edf @ 32 Hz
# Predicting file edf_data\Af8a.edf @ 32 Hz
# Predicting file edf_data\AsLD.edf @ 32 Hz
# Predicting file edf_data\AXbm.edf @ 32 Hz
# Predicting file edf_data\bkx9.edf @ 32 Hz
# Predicting file edf_data\BSvO.edf @ 32 Hz
# Predicting file edf_data\C1Wu.edf @ 32 Hz
# Predicting file edf_data\cblr.edf @ 32 Hz
# Predicting file edf_data\csxQ.edf @ 32 Hz
# Predicting file edf_data\d3ET.edf @ 32 Hz
# Predicting file edf_data\ddTG.edf @ 32 Hz
# Predicting file edf_data\DjrT.edf @ 32 Hz
# Predicting file edf_data\Dr51.edf @ 32 Hz
# Predicting file edf_data\DSfb.edf @ 32 Hz
# Predicting file edf_data\DYYI.edf @ 32 Hz
# Predicting file edf_data\EHED.edf @ 32 Hz
# Predicting file edf_data\EMcQ.edf @ 32 Hz
# Predicting file edf_data\EyTS.edf @ 32 Hz
# Predicting file edf_data\f8H5.edf @ 32 Hz
# Predicting file edf_data\fNe4.edf @ 32 Hz
# Predicting file edf_data\fT68.edf @ 32 Hz
# Predicting file edf_data\G7PJ.edf @ 32 Hz
# Predicting file edf_data\go56.edf @ 32 Hz
# Predicting file edf_data\hcml.edf @ 32 Hz
# Predicting file edf_data\hRMy.edf @ 32 Hz
# Predicting file edf_data\hT38.edf @ 32 Hz
# Predicting file edf_data\ibbz.edf @ 32 Hz
# Predicting file edf_data\IhpU.edf @ 32 Hz
# Predicting file edf_data\ipxV.edf @ 32 Hz
# Predicting file edf_data\iSqw.edf @ 32 Hz
# Predicting file edf_data\Ivfn.edf @ 32 Hz
# Predicting file edf_data\JCpz.edf @ 32 Hz
# Predicting file edf_data\kj2l.edf @ 32 Hz
# Predicting file edf_data\Kn9O.edf @ 32 Hz
# Predicting file edf_data\LR2s.edf @ 32 Hz
# Predicting file edf_data\mBks.edf @ 32 Hz
# Predicting file edf_data\MS6u.edf @ 32 Hz
# Predicting file edf_data\Msy4.edf @ 32 Hz
# Predicting file edf_data\muls.edf @ 32 Hz
# Predicting file edf_data\mZje.edf @ 32 Hz
# Predicting file edf_data\N1nM.edf @ 32 Hz
# Predicting file edf_data\Nzhl.edf @ 32 Hz
# Predicting file edf_data\oOMR.edf @ 32 Hz
# Predicting file edf_data\Otq3.edf @ 32 Hz
# Predicting file edf_data\pPpj.edf @ 32 Hz
# Predicting file edf_data\puoa.edf @ 32 Hz
# Predicting file edf_data\QDsa.edf @ 32 Hz
# Predicting file edf_data\R2f3.edf @ 32 Hz
# Predicting file edf_data\RfL0.edf @ 32 Hz
# Predicting file edf_data\RM1S.edf @ 32 Hz
# Predicting file edf_data\sNMf.edf @ 32 Hz
# Predicting file edf_data\SOZ3.edf @ 32 Hz
# Predicting file edf_data\svlu.edf @ 32 Hz
# Predicting file edf_data\tG6i.edf @ 32 Hz
# Predicting file edf_data\UsSz.edf @ 32 Hz
# Predicting file edf_data\UwK6.edf @ 32 Hz
# Predicting file edf_data\uXdB.edf @ 32 Hz
# Predicting file edf_data\X7s0.edf @ 32 Hz
# Predicting file edf_data\Xg1l.edf @ 32 Hz
# Predicting file edf_data\Xii6.edf @ 32 Hz
# Predicting file edf_data\Y4FK.edf @ 32 Hz
# Predicting file edf_data\y5We.edf @ 32 Hz
# Predicting file edf_data\YHLr.edf @ 32 Hz
# Predicting file edf_data\YOh8.edf @ 32 Hz
# Predicting file edf_data\zaca.edf @ 32 Hz
# Predicting file edf_data\Zpwh.edf @ 32 Hz
# Predicting file edf_data\ZYFG.edf @ 32 Hz

# %% [markdown]
# ### Convert predictions (.npy) to matlab format (.mat)

# %%
import numpy as np
import scipy.io
npy_files = glob.glob("predictions/*/*.npy")

for file in npy_files:
    tmp = np.load(file)
    out_file = f"Matlab\\{file.replace('.npy','.mat')}"
    print(f"Saving {file} as .mat: {out_file}")
    scipy.io.savemat(out_file, dict(data=tmp))
# Out:
# Saving predictions\128_hz\0ncr.npy as .mat: Matlab\predictions\128_hz\0ncr.mat
# Saving predictions\128_hz\0pai.npy as .mat: Matlab\predictions\128_hz\0pai.mat
# Saving predictions\128_hz\3J4W.npy as .mat: Matlab\predictions\128_hz\3J4W.mat
# Saving predictions\128_hz\3P0D.npy as .mat: Matlab\predictions\128_hz\3P0D.mat
# Saving predictions\128_hz\40kO.npy as .mat: Matlab\predictions\128_hz\40kO.mat
# Saving predictions\128_hz\5bSg.npy as .mat: Matlab\predictions\128_hz\5bSg.mat
# Saving predictions\128_hz\6iwd.npy as .mat: Matlab\predictions\128_hz\6iwd.mat
# Saving predictions\128_hz\6JVj.npy as .mat: Matlab\predictions\128_hz\6JVj.mat
# Saving predictions\128_hz\9098.npy as .mat: Matlab\predictions\128_hz\9098.mat
# Saving predictions\128_hz\9JQY.npy as .mat: Matlab\predictions\128_hz\9JQY.mat
# Saving predictions\128_hz\Af8a.npy as .mat: Matlab\predictions\128_hz\Af8a.mat
# Saving predictions\128_hz\AsLD.npy as .mat: Matlab\predictions\128_hz\AsLD.mat
# Saving predictions\128_hz\AXbm.npy as .mat: Matlab\predictions\128_hz\AXbm.mat
# Saving predictions\128_hz\bkx9.npy as .mat: Matlab\predictions\128_hz\bkx9.mat
# Saving predictions\128_hz\BSvO.npy as .mat: Matlab\predictions\128_hz\BSvO.mat
# Saving predictions\128_hz\C1Wu.npy as .mat: Matlab\predictions\128_hz\C1Wu.mat
# Saving predictions\128_hz\cblr.npy as .mat: Matlab\predictions\128_hz\cblr.mat
# Saving predictions\128_hz\csxQ.npy as .mat: Matlab\predictions\128_hz\csxQ.mat
# Saving predictions\128_hz\d3ET.npy as .mat: Matlab\predictions\128_hz\d3ET.mat
# Saving predictions\128_hz\ddTG.npy as .mat: Matlab\predictions\128_hz\ddTG.mat
# Saving predictions\128_hz\DjrT.npy as .mat: Matlab\predictions\128_hz\DjrT.mat
# Saving predictions\128_hz\Dr51.npy as .mat: Matlab\predictions\128_hz\Dr51.mat
# Saving predictions\128_hz\DSfb.npy as .mat: Matlab\predictions\128_hz\DSfb.mat
# Saving predictions\128_hz\DYYI.npy as .mat: Matlab\predictions\128_hz\DYYI.mat
# Saving predictions\128_hz\EHED.npy as .mat: Matlab\predictions\128_hz\EHED.mat
# Saving predictions\128_hz\EMcQ.npy as .mat: Matlab\predictions\128_hz\EMcQ.mat
# Saving predictions\128_hz\EyTS.npy as .mat: Matlab\predictions\128_hz\EyTS.mat
# Saving predictions\128_hz\f8H5.npy as .mat: Matlab\predictions\128_hz\f8H5.mat
# Saving predictions\128_hz\fNe4.npy as .mat: Matlab\predictions\128_hz\fNe4.mat
# Saving predictions\128_hz\fT68.npy as .mat: Matlab\predictions\128_hz\fT68.mat
# Saving predictions\128_hz\G7PJ.npy as .mat: Matlab\predictions\128_hz\G7PJ.mat
# Saving predictions\128_hz\go56.npy as .mat: Matlab\predictions\128_hz\go56.mat
# Saving predictions\128_hz\hcml.npy as .mat: Matlab\predictions\128_hz\hcml.mat
# Saving predictions\128_hz\hRMy.npy as .mat: Matlab\predictions\128_hz\hRMy.mat
# Saving predictions\128_hz\hT38.npy as .mat: Matlab\predictions\128_hz\hT38.mat
# Saving predictions\128_hz\ibbz.npy as .mat: Matlab\predictions\128_hz\ibbz.mat
# Saving predictions\128_hz\IhpU.npy as .mat: Matlab\predictions\128_hz\IhpU.mat
# Saving predictions\128_hz\ipxV.npy as .mat: Matlab\predictions\128_hz\ipxV.mat
# Saving predictions\128_hz\iSqw.npy as .mat: Matlab\predictions\128_hz\iSqw.mat
# Saving predictions\128_hz\Ivfn.npy as .mat: Matlab\predictions\128_hz\Ivfn.mat
# Saving predictions\128_hz\JCpz.npy as .mat: Matlab\predictions\128_hz\JCpz.mat
# Saving predictions\128_hz\kj2l.npy as .mat: Matlab\predictions\128_hz\kj2l.mat
# Saving predictions\128_hz\Kn9O.npy as .mat: Matlab\predictions\128_hz\Kn9O.mat
# Saving predictions\128_hz\LR2s.npy as .mat: Matlab\predictions\128_hz\LR2s.mat
# Saving predictions\128_hz\mBks.npy as .mat: Matlab\predictions\128_hz\mBks.mat
# Saving predictions\128_hz\MS6u.npy as .mat: Matlab\predictions\128_hz\MS6u.mat
# Saving predictions\128_hz\Msy4.npy as .mat: Matlab\predictions\128_hz\Msy4.mat
# Saving predictions\128_hz\muls.npy as .mat: Matlab\predictions\128_hz\muls.mat
# Saving predictions\128_hz\mZje.npy as .mat: Matlab\predictions\128_hz\mZje.mat
# Saving predictions\128_hz\N1nM.npy as .mat: Matlab\predictions\128_hz\N1nM.mat
# Saving predictions\128_hz\Nzhl.npy as .mat: Matlab\predictions\128_hz\Nzhl.mat
# Saving predictions\128_hz\oOMR.npy as .mat: Matlab\predictions\128_hz\oOMR.mat
# Saving predictions\128_hz\Otq3.npy as .mat: Matlab\predictions\128_hz\Otq3.mat
# Saving predictions\128_hz\pPpj.npy as .mat: Matlab\predictions\128_hz\pPpj.mat
# Saving predictions\128_hz\puoa.npy as .mat: Matlab\predictions\128_hz\puoa.mat
# Saving predictions\128_hz\QDsa.npy as .mat: Matlab\predictions\128_hz\QDsa.mat
# Saving predictions\128_hz\R2f3.npy as .mat: Matlab\predictions\128_hz\R2f3.mat
# Saving predictions\128_hz\RfL0.npy as .mat: Matlab\predictions\128_hz\RfL0.mat
# Saving predictions\128_hz\RM1S.npy as .mat: Matlab\predictions\128_hz\RM1S.mat
# Saving predictions\128_hz\sNMf.npy as .mat: Matlab\predictions\128_hz\sNMf.mat
# Saving predictions\128_hz\SOZ3.npy as .mat: Matlab\predictions\128_hz\SOZ3.mat
# Saving predictions\128_hz\svlu.npy as .mat: Matlab\predictions\128_hz\svlu.mat
# Saving predictions\128_hz\tG6i.npy as .mat: Matlab\predictions\128_hz\tG6i.mat
# Saving predictions\128_hz\UsSz.npy as .mat: Matlab\predictions\128_hz\UsSz.mat
# Saving predictions\128_hz\UwK6.npy as .mat: Matlab\predictions\128_hz\UwK6.mat
# Saving predictions\128_hz\uXdB.npy as .mat: Matlab\predictions\128_hz\uXdB.mat
# Saving predictions\128_hz\X7s0.npy as .mat: Matlab\predictions\128_hz\X7s0.mat
# Saving predictions\128_hz\Xg1l.npy as .mat: Matlab\predictions\128_hz\Xg1l.mat
# Saving predictions\128_hz\Xii6.npy as .mat: Matlab\predictions\128_hz\Xii6.mat
# Saving predictions\128_hz\Y4FK.npy as .mat: Matlab\predictions\128_hz\Y4FK.mat
# Saving predictions\128_hz\y5We.npy as .mat: Matlab\predictions\128_hz\y5We.mat
# Saving predictions\128_hz\YHLr.npy as .mat: Matlab\predictions\128_hz\YHLr.mat
# Saving predictions\128_hz\YOh8.npy as .mat: Matlab\predictions\128_hz\YOh8.mat
# Saving predictions\128_hz\zaca.npy as .mat: Matlab\predictions\128_hz\zaca.mat
# Saving predictions\128_hz\Zpwh.npy as .mat: Matlab\predictions\128_hz\Zpwh.mat
# Saving predictions\128_hz\ZYFG.npy as .mat: Matlab\predictions\128_hz\ZYFG.mat
# Saving predictions\16_hz\0ncr.npy as .mat: Matlab\predictions\16_hz\0ncr.mat
# Saving predictions\16_hz\0pai.npy as .mat: Matlab\predictions\16_hz\0pai.mat
# Saving predictions\16_hz\3J4W.npy as .mat: Matlab\predictions\16_hz\3J4W.mat
# Saving predictions\16_hz\3P0D.npy as .mat: Matlab\predictions\16_hz\3P0D.mat
# Saving predictions\16_hz\40kO.npy as .mat: Matlab\predictions\16_hz\40kO.mat
# Saving predictions\16_hz\5bSg.npy as .mat: Matlab\predictions\16_hz\5bSg.mat
# Saving predictions\16_hz\6iwd.npy as .mat: Matlab\predictions\16_hz\6iwd.mat
# Saving predictions\16_hz\6JVj.npy as .mat: Matlab\predictions\16_hz\6JVj.mat
# Saving predictions\16_hz\9098.npy as .mat: Matlab\predictions\16_hz\9098.mat
# Saving predictions\16_hz\9JQY.npy as .mat: Matlab\predictions\16_hz\9JQY.mat
# Saving predictions\16_hz\Af8a.npy as .mat: Matlab\predictions\16_hz\Af8a.mat
# Saving predictions\16_hz\AsLD.npy as .mat: Matlab\predictions\16_hz\AsLD.mat
# Saving predictions\16_hz\AXbm.npy as .mat: Matlab\predictions\16_hz\AXbm.mat
# Saving predictions\16_hz\bkx9.npy as .mat: Matlab\predictions\16_hz\bkx9.mat
# Saving predictions\16_hz\BSvO.npy as .mat: Matlab\predictions\16_hz\BSvO.mat
# Saving predictions\16_hz\C1Wu.npy as .mat: Matlab\predictions\16_hz\C1Wu.mat
# Saving predictions\16_hz\cblr.npy as .mat: Matlab\predictions\16_hz\cblr.mat
# Saving predictions\16_hz\csxQ.npy as .mat: Matlab\predictions\16_hz\csxQ.mat
# Saving predictions\16_hz\d3ET.npy as .mat: Matlab\predictions\16_hz\d3ET.mat
# Saving predictions\16_hz\ddTG.npy as .mat: Matlab\predictions\16_hz\ddTG.mat
# Saving predictions\16_hz\DjrT.npy as .mat: Matlab\predictions\16_hz\DjrT.mat
# Saving predictions\16_hz\Dr51.npy as .mat: Matlab\predictions\16_hz\Dr51.mat
# Saving predictions\16_hz\DSfb.npy as .mat: Matlab\predictions\16_hz\DSfb.mat
# Saving predictions\16_hz\DYYI.npy as .mat: Matlab\predictions\16_hz\DYYI.mat
# Saving predictions\16_hz\EHED.npy as .mat: Matlab\predictions\16_hz\EHED.mat
# Saving predictions\16_hz\EMcQ.npy as .mat: Matlab\predictions\16_hz\EMcQ.mat
# Saving predictions\16_hz\EyTS.npy as .mat: Matlab\predictions\16_hz\EyTS.mat
# Saving predictions\16_hz\f8H5.npy as .mat: Matlab\predictions\16_hz\f8H5.mat
# Saving predictions\16_hz\fNe4.npy as .mat: Matlab\predictions\16_hz\fNe4.mat
# Saving predictions\16_hz\fT68.npy as .mat: Matlab\predictions\16_hz\fT68.mat
# Saving predictions\16_hz\G7PJ.npy as .mat: Matlab\predictions\16_hz\G7PJ.mat
# Saving predictions\16_hz\go56.npy as .mat: Matlab\predictions\16_hz\go56.mat
# Saving predictions\16_hz\hcml.npy as .mat: Matlab\predictions\16_hz\hcml.mat
# Saving predictions\16_hz\hRMy.npy as .mat: Matlab\predictions\16_hz\hRMy.mat
# Saving predictions\16_hz\hT38.npy as .mat: Matlab\predictions\16_hz\hT38.mat
# Saving predictions\16_hz\ibbz.npy as .mat: Matlab\predictions\16_hz\ibbz.mat
# Saving predictions\16_hz\IhpU.npy as .mat: Matlab\predictions\16_hz\IhpU.mat
# Saving predictions\16_hz\ipxV.npy as .mat: Matlab\predictions\16_hz\ipxV.mat
# Saving predictions\16_hz\iSqw.npy as .mat: Matlab\predictions\16_hz\iSqw.mat
# Saving predictions\16_hz\Ivfn.npy as .mat: Matlab\predictions\16_hz\Ivfn.mat
# Saving predictions\16_hz\JCpz.npy as .mat: Matlab\predictions\16_hz\JCpz.mat
# Saving predictions\16_hz\kj2l.npy as .mat: Matlab\predictions\16_hz\kj2l.mat
# Saving predictions\16_hz\Kn9O.npy as .mat: Matlab\predictions\16_hz\Kn9O.mat
# Saving predictions\16_hz\LR2s.npy as .mat: Matlab\predictions\16_hz\LR2s.mat
# Saving predictions\16_hz\mBks.npy as .mat: Matlab\predictions\16_hz\mBks.mat
# Saving predictions\16_hz\MS6u.npy as .mat: Matlab\predictions\16_hz\MS6u.mat
# Saving predictions\16_hz\Msy4.npy as .mat: Matlab\predictions\16_hz\Msy4.mat
# Saving predictions\16_hz\muls.npy as .mat: Matlab\predictions\16_hz\muls.mat
# Saving predictions\16_hz\mZje.npy as .mat: Matlab\predictions\16_hz\mZje.mat
# Saving predictions\16_hz\N1nM.npy as .mat: Matlab\predictions\16_hz\N1nM.mat
# Saving predictions\16_hz\Nzhl.npy as .mat: Matlab\predictions\16_hz\Nzhl.mat
# Saving predictions\16_hz\oOMR.npy as .mat: Matlab\predictions\16_hz\oOMR.mat
# Saving predictions\16_hz\Otq3.npy as .mat: Matlab\predictions\16_hz\Otq3.mat
# Saving predictions\16_hz\pPpj.npy as .mat: Matlab\predictions\16_hz\pPpj.mat
# Saving predictions\16_hz\puoa.npy as .mat: Matlab\predictions\16_hz\puoa.mat
# Saving predictions\16_hz\QDsa.npy as .mat: Matlab\predictions\16_hz\QDsa.mat
# Saving predictions\16_hz\R2f3.npy as .mat: Matlab\predictions\16_hz\R2f3.mat
# Saving predictions\16_hz\RfL0.npy as .mat: Matlab\predictions\16_hz\RfL0.mat
# Saving predictions\16_hz\RM1S.npy as .mat: Matlab\predictions\16_hz\RM1S.mat
# Saving predictions\16_hz\sNMf.npy as .mat: Matlab\predictions\16_hz\sNMf.mat
# Saving predictions\16_hz\SOZ3.npy as .mat: Matlab\predictions\16_hz\SOZ3.mat
# Saving predictions\16_hz\svlu.npy as .mat: Matlab\predictions\16_hz\svlu.mat
# Saving predictions\16_hz\tG6i.npy as .mat: Matlab\predictions\16_hz\tG6i.mat
# Saving predictions\16_hz\UsSz.npy as .mat: Matlab\predictions\16_hz\UsSz.mat
# Saving predictions\16_hz\UwK6.npy as .mat: Matlab\predictions\16_hz\UwK6.mat
# Saving predictions\16_hz\uXdB.npy as .mat: Matlab\predictions\16_hz\uXdB.mat
# Saving predictions\16_hz\X7s0.npy as .mat: Matlab\predictions\16_hz\X7s0.mat
# Saving predictions\16_hz\Xg1l.npy as .mat: Matlab\predictions\16_hz\Xg1l.mat
# Saving predictions\16_hz\Xii6.npy as .mat: Matlab\predictions\16_hz\Xii6.mat
# Saving predictions\16_hz\Y4FK.npy as .mat: Matlab\predictions\16_hz\Y4FK.mat
# Saving predictions\16_hz\y5We.npy as .mat: Matlab\predictions\16_hz\y5We.mat
# Saving predictions\16_hz\YHLr.npy as .mat: Matlab\predictions\16_hz\YHLr.mat
# Saving predictions\16_hz\YOh8.npy as .mat: Matlab\predictions\16_hz\YOh8.mat
# Saving predictions\16_hz\zaca.npy as .mat: Matlab\predictions\16_hz\zaca.mat
# Saving predictions\16_hz\Zpwh.npy as .mat: Matlab\predictions\16_hz\Zpwh.mat
# Saving predictions\16_hz\ZYFG.npy as .mat: Matlab\predictions\16_hz\ZYFG.mat
# Saving predictions\1_hz\0ncr.npy as .mat: Matlab\predictions\1_hz\0ncr.mat
# Saving predictions\1_hz\0pai.npy as .mat: Matlab\predictions\1_hz\0pai.mat
# Saving predictions\1_hz\3J4W.npy as .mat: Matlab\predictions\1_hz\3J4W.mat
# Saving predictions\1_hz\3P0D.npy as .mat: Matlab\predictions\1_hz\3P0D.mat
# Saving predictions\1_hz\40kO.npy as .mat: Matlab\predictions\1_hz\40kO.mat
# Saving predictions\1_hz\5bSg.npy as .mat: Matlab\predictions\1_hz\5bSg.mat
# Saving predictions\1_hz\6iwd.npy as .mat: Matlab\predictions\1_hz\6iwd.mat
# Saving predictions\1_hz\6JVj.npy as .mat: Matlab\predictions\1_hz\6JVj.mat
# Saving predictions\1_hz\9098.npy as .mat: Matlab\predictions\1_hz\9098.mat
# Saving predictions\1_hz\9JQY.npy as .mat: Matlab\predictions\1_hz\9JQY.mat
# Saving predictions\1_hz\Af8a.npy as .mat: Matlab\predictions\1_hz\Af8a.mat
# Saving predictions\1_hz\AsLD.npy as .mat: Matlab\predictions\1_hz\AsLD.mat
# Saving predictions\1_hz\AXbm.npy as .mat: Matlab\predictions\1_hz\AXbm.mat
# Saving predictions\1_hz\bkx9.npy as .mat: Matlab\predictions\1_hz\bkx9.mat
# Saving predictions\1_hz\BSvO.npy as .mat: Matlab\predictions\1_hz\BSvO.mat
# Saving predictions\1_hz\C1Wu.npy as .mat: Matlab\predictions\1_hz\C1Wu.mat
# Saving predictions\1_hz\cblr.npy as .mat: Matlab\predictions\1_hz\cblr.mat
# Saving predictions\1_hz\csxQ.npy as .mat: Matlab\predictions\1_hz\csxQ.mat
# Saving predictions\1_hz\d3ET.npy as .mat: Matlab\predictions\1_hz\d3ET.mat
# Saving predictions\1_hz\ddTG.npy as .mat: Matlab\predictions\1_hz\ddTG.mat
# Saving predictions\1_hz\DjrT.npy as .mat: Matlab\predictions\1_hz\DjrT.mat
# Saving predictions\1_hz\Dr51.npy as .mat: Matlab\predictions\1_hz\Dr51.mat
# Saving predictions\1_hz\DSfb.npy as .mat: Matlab\predictions\1_hz\DSfb.mat
# Saving predictions\1_hz\DYYI.npy as .mat: Matlab\predictions\1_hz\DYYI.mat
# Saving predictions\1_hz\EHED.npy as .mat: Matlab\predictions\1_hz\EHED.mat
# Saving predictions\1_hz\EMcQ.npy as .mat: Matlab\predictions\1_hz\EMcQ.mat
# Saving predictions\1_hz\EyTS.npy as .mat: Matlab\predictions\1_hz\EyTS.mat
# Saving predictions\1_hz\f8H5.npy as .mat: Matlab\predictions\1_hz\f8H5.mat
# Saving predictions\1_hz\fNe4.npy as .mat: Matlab\predictions\1_hz\fNe4.mat
# Saving predictions\1_hz\fT68.npy as .mat: Matlab\predictions\1_hz\fT68.mat
# Saving predictions\1_hz\G7PJ.npy as .mat: Matlab\predictions\1_hz\G7PJ.mat
# Saving predictions\1_hz\go56.npy as .mat: Matlab\predictions\1_hz\go56.mat
# Saving predictions\1_hz\hcml.npy as .mat: Matlab\predictions\1_hz\hcml.mat
# Saving predictions\1_hz\hRMy.npy as .mat: Matlab\predictions\1_hz\hRMy.mat
# Saving predictions\1_hz\hT38.npy as .mat: Matlab\predictions\1_hz\hT38.mat
# Saving predictions\1_hz\ibbz.npy as .mat: Matlab\predictions\1_hz\ibbz.mat
# Saving predictions\1_hz\IhpU.npy as .mat: Matlab\predictions\1_hz\IhpU.mat
# Saving predictions\1_hz\ipxV.npy as .mat: Matlab\predictions\1_hz\ipxV.mat
# Saving predictions\1_hz\iSqw.npy as .mat: Matlab\predictions\1_hz\iSqw.mat
# Saving predictions\1_hz\Ivfn.npy as .mat: Matlab\predictions\1_hz\Ivfn.mat
# Saving predictions\1_hz\JCpz.npy as .mat: Matlab\predictions\1_hz\JCpz.mat
# Saving predictions\1_hz\kj2l.npy as .mat: Matlab\predictions\1_hz\kj2l.mat
# Saving predictions\1_hz\Kn9O.npy as .mat: Matlab\predictions\1_hz\Kn9O.mat
# Saving predictions\1_hz\LR2s.npy as .mat: Matlab\predictions\1_hz\LR2s.mat
# Saving predictions\1_hz\mBks.npy as .mat: Matlab\predictions\1_hz\mBks.mat
# Saving predictions\1_hz\MS6u.npy as .mat: Matlab\predictions\1_hz\MS6u.mat
# Saving predictions\1_hz\Msy4.npy as .mat: Matlab\predictions\1_hz\Msy4.mat
# Saving predictions\1_hz\muls.npy as .mat: Matlab\predictions\1_hz\muls.mat
# Saving predictions\1_hz\mZje.npy as .mat: Matlab\predictions\1_hz\mZje.mat
# Saving predictions\1_hz\N1nM.npy as .mat: Matlab\predictions\1_hz\N1nM.mat
# Saving predictions\1_hz\Nzhl.npy as .mat: Matlab\predictions\1_hz\Nzhl.mat
# Saving predictions\1_hz\oOMR.npy as .mat: Matlab\predictions\1_hz\oOMR.mat
# Saving predictions\1_hz\Otq3.npy as .mat: Matlab\predictions\1_hz\Otq3.mat
# Saving predictions\1_hz\pPpj.npy as .mat: Matlab\predictions\1_hz\pPpj.mat
# Saving predictions\1_hz\puoa.npy as .mat: Matlab\predictions\1_hz\puoa.mat
# Saving predictions\1_hz\QDsa.npy as .mat: Matlab\predictions\1_hz\QDsa.mat
# Saving predictions\1_hz\R2f3.npy as .mat: Matlab\predictions\1_hz\R2f3.mat
# Saving predictions\1_hz\RfL0.npy as .mat: Matlab\predictions\1_hz\RfL0.mat
# Saving predictions\1_hz\RM1S.npy as .mat: Matlab\predictions\1_hz\RM1S.mat
# Saving predictions\1_hz\sNMf.npy as .mat: Matlab\predictions\1_hz\sNMf.mat
# Saving predictions\1_hz\SOZ3.npy as .mat: Matlab\predictions\1_hz\SOZ3.mat
# Saving predictions\1_hz\svlu.npy as .mat: Matlab\predictions\1_hz\svlu.mat
# Saving predictions\1_hz\tG6i.npy as .mat: Matlab\predictions\1_hz\tG6i.mat
# Saving predictions\1_hz\UsSz.npy as .mat: Matlab\predictions\1_hz\UsSz.mat
# Saving predictions\1_hz\UwK6.npy as .mat: Matlab\predictions\1_hz\UwK6.mat
# Saving predictions\1_hz\uXdB.npy as .mat: Matlab\predictions\1_hz\uXdB.mat
# Saving predictions\1_hz\X7s0.npy as .mat: Matlab\predictions\1_hz\X7s0.mat
# Saving predictions\1_hz\Xg1l.npy as .mat: Matlab\predictions\1_hz\Xg1l.mat
# Saving predictions\1_hz\Xii6.npy as .mat: Matlab\predictions\1_hz\Xii6.mat
# Saving predictions\1_hz\Y4FK.npy as .mat: Matlab\predictions\1_hz\Y4FK.mat
# Saving predictions\1_hz\y5We.npy as .mat: Matlab\predictions\1_hz\y5We.mat
# Saving predictions\1_hz\YHLr.npy as .mat: Matlab\predictions\1_hz\YHLr.mat
# Saving predictions\1_hz\YOh8.npy as .mat: Matlab\predictions\1_hz\YOh8.mat
# Saving predictions\1_hz\zaca.npy as .mat: Matlab\predictions\1_hz\zaca.mat
# Saving predictions\1_hz\Zpwh.npy as .mat: Matlab\predictions\1_hz\Zpwh.mat
# Saving predictions\1_hz\ZYFG.npy as .mat: Matlab\predictions\1_hz\ZYFG.mat
# Saving predictions\32_hz\0ncr.npy as .mat: Matlab\predictions\32_hz\0ncr.mat
# Saving predictions\32_hz\0pai.npy as .mat: Matlab\predictions\32_hz\0pai.mat
# Saving predictions\32_hz\3J4W.npy as .mat: Matlab\predictions\32_hz\3J4W.mat
# Saving predictions\32_hz\3P0D.npy as .mat: Matlab\predictions\32_hz\3P0D.mat
# Saving predictions\32_hz\40kO.npy as .mat: Matlab\predictions\32_hz\40kO.mat
# Saving predictions\32_hz\5bSg.npy as .mat: Matlab\predictions\32_hz\5bSg.mat
# Saving predictions\32_hz\6iwd.npy as .mat: Matlab\predictions\32_hz\6iwd.mat
# Saving predictions\32_hz\6JVj.npy as .mat: Matlab\predictions\32_hz\6JVj.mat
# Saving predictions\32_hz\9098.npy as .mat: Matlab\predictions\32_hz\9098.mat
# Saving predictions\32_hz\9JQY.npy as .mat: Matlab\predictions\32_hz\9JQY.mat
# Saving predictions\32_hz\Af8a.npy as .mat: Matlab\predictions\32_hz\Af8a.mat
# Saving predictions\32_hz\AsLD.npy as .mat: Matlab\predictions\32_hz\AsLD.mat
# Saving predictions\32_hz\AXbm.npy as .mat: Matlab\predictions\32_hz\AXbm.mat
# Saving predictions\32_hz\bkx9.npy as .mat: Matlab\predictions\32_hz\bkx9.mat
# Saving predictions\32_hz\BSvO.npy as .mat: Matlab\predictions\32_hz\BSvO.mat
# Saving predictions\32_hz\C1Wu.npy as .mat: Matlab\predictions\32_hz\C1Wu.mat
# Saving predictions\32_hz\cblr.npy as .mat: Matlab\predictions\32_hz\cblr.mat
# Saving predictions\32_hz\csxQ.npy as .mat: Matlab\predictions\32_hz\csxQ.mat
# Saving predictions\32_hz\d3ET.npy as .mat: Matlab\predictions\32_hz\d3ET.mat
# Saving predictions\32_hz\ddTG.npy as .mat: Matlab\predictions\32_hz\ddTG.mat
# Saving predictions\32_hz\DjrT.npy as .mat: Matlab\predictions\32_hz\DjrT.mat
# Saving predictions\32_hz\Dr51.npy as .mat: Matlab\predictions\32_hz\Dr51.mat
# Saving predictions\32_hz\DSfb.npy as .mat: Matlab\predictions\32_hz\DSfb.mat
# Saving predictions\32_hz\DYYI.npy as .mat: Matlab\predictions\32_hz\DYYI.mat
# Saving predictions\32_hz\EHED.npy as .mat: Matlab\predictions\32_hz\EHED.mat
# Saving predictions\32_hz\EMcQ.npy as .mat: Matlab\predictions\32_hz\EMcQ.mat
# Saving predictions\32_hz\EyTS.npy as .mat: Matlab\predictions\32_hz\EyTS.mat
# Saving predictions\32_hz\f8H5.npy as .mat: Matlab\predictions\32_hz\f8H5.mat
# Saving predictions\32_hz\fNe4.npy as .mat: Matlab\predictions\32_hz\fNe4.mat
# Saving predictions\32_hz\fT68.npy as .mat: Matlab\predictions\32_hz\fT68.mat
# Saving predictions\32_hz\G7PJ.npy as .mat: Matlab\predictions\32_hz\G7PJ.mat
# Saving predictions\32_hz\go56.npy as .mat: Matlab\predictions\32_hz\go56.mat
# Saving predictions\32_hz\hcml.npy as .mat: Matlab\predictions\32_hz\hcml.mat
# Saving predictions\32_hz\hRMy.npy as .mat: Matlab\predictions\32_hz\hRMy.mat
# Saving predictions\32_hz\hT38.npy as .mat: Matlab\predictions\32_hz\hT38.mat
# Saving predictions\32_hz\ibbz.npy as .mat: Matlab\predictions\32_hz\ibbz.mat
# Saving predictions\32_hz\IhpU.npy as .mat: Matlab\predictions\32_hz\IhpU.mat
# Saving predictions\32_hz\ipxV.npy as .mat: Matlab\predictions\32_hz\ipxV.mat
# Saving predictions\32_hz\iSqw.npy as .mat: Matlab\predictions\32_hz\iSqw.mat
# Saving predictions\32_hz\Ivfn.npy as .mat: Matlab\predictions\32_hz\Ivfn.mat
# Saving predictions\32_hz\JCpz.npy as .mat: Matlab\predictions\32_hz\JCpz.mat
# Saving predictions\32_hz\kj2l.npy as .mat: Matlab\predictions\32_hz\kj2l.mat
# Saving predictions\32_hz\Kn9O.npy as .mat: Matlab\predictions\32_hz\Kn9O.mat
# Saving predictions\32_hz\LR2s.npy as .mat: Matlab\predictions\32_hz\LR2s.mat
# Saving predictions\32_hz\mBks.npy as .mat: Matlab\predictions\32_hz\mBks.mat
# Saving predictions\32_hz\MS6u.npy as .mat: Matlab\predictions\32_hz\MS6u.mat
# Saving predictions\32_hz\Msy4.npy as .mat: Matlab\predictions\32_hz\Msy4.mat
# Saving predictions\32_hz\muls.npy as .mat: Matlab\predictions\32_hz\muls.mat
# Saving predictions\32_hz\mZje.npy as .mat: Matlab\predictions\32_hz\mZje.mat
# Saving predictions\32_hz\N1nM.npy as .mat: Matlab\predictions\32_hz\N1nM.mat
# Saving predictions\32_hz\Nzhl.npy as .mat: Matlab\predictions\32_hz\Nzhl.mat
# Saving predictions\32_hz\oOMR.npy as .mat: Matlab\predictions\32_hz\oOMR.mat
# Saving predictions\32_hz\Otq3.npy as .mat: Matlab\predictions\32_hz\Otq3.mat
# Saving predictions\32_hz\pPpj.npy as .mat: Matlab\predictions\32_hz\pPpj.mat
# Saving predictions\32_hz\puoa.npy as .mat: Matlab\predictions\32_hz\puoa.mat
# Saving predictions\32_hz\QDsa.npy as .mat: Matlab\predictions\32_hz\QDsa.mat
# Saving predictions\32_hz\R2f3.npy as .mat: Matlab\predictions\32_hz\R2f3.mat
# Saving predictions\32_hz\RfL0.npy as .mat: Matlab\predictions\32_hz\RfL0.mat
# Saving predictions\32_hz\RM1S.npy as .mat: Matlab\predictions\32_hz\RM1S.mat
# Saving predictions\32_hz\sNMf.npy as .mat: Matlab\predictions\32_hz\sNMf.mat
# Saving predictions\32_hz\SOZ3.npy as .mat: Matlab\predictions\32_hz\SOZ3.mat
# Saving predictions\32_hz\svlu.npy as .mat: Matlab\predictions\32_hz\svlu.mat
# Saving predictions\32_hz\tG6i.npy as .mat: Matlab\predictions\32_hz\tG6i.mat
# Saving predictions\32_hz\UsSz.npy as .mat: Matlab\predictions\32_hz\UsSz.mat
# Saving predictions\32_hz\UwK6.npy as .mat: Matlab\predictions\32_hz\UwK6.mat
# Saving predictions\32_hz\uXdB.npy as .mat: Matlab\predictions\32_hz\uXdB.mat
# Saving predictions\32_hz\X7s0.npy as .mat: Matlab\predictions\32_hz\X7s0.mat
# Saving predictions\32_hz\Xg1l.npy as .mat: Matlab\predictions\32_hz\Xg1l.mat
# Saving predictions\32_hz\Xii6.npy as .mat: Matlab\predictions\32_hz\Xii6.mat
# Saving predictions\32_hz\Y4FK.npy as .mat: Matlab\predictions\32_hz\Y4FK.mat
# Saving predictions\32_hz\y5We.npy as .mat: Matlab\predictions\32_hz\y5We.mat
# Saving predictions\32_hz\YHLr.npy as .mat: Matlab\predictions\32_hz\YHLr.mat
# Saving predictions\32_hz\YOh8.npy as .mat: Matlab\predictions\32_hz\YOh8.mat
# Saving predictions\32_hz\zaca.npy as .mat: Matlab\predictions\32_hz\zaca.mat
# Saving predictions\32_hz\Zpwh.npy as .mat: Matlab\predictions\32_hz\Zpwh.mat
# Saving predictions\32_hz\ZYFG.npy as .mat: Matlab\predictions\32_hz\ZYFG.mat
# Saving predictions\64_hz\0ncr.npy as .mat: Matlab\predictions\64_hz\0ncr.mat
# Saving predictions\64_hz\0pai.npy as .mat: Matlab\predictions\64_hz\0pai.mat
# Saving predictions\64_hz\3J4W.npy as .mat: Matlab\predictions\64_hz\3J4W.mat
# Saving predictions\64_hz\3P0D.npy as .mat: Matlab\predictions\64_hz\3P0D.mat
# Saving predictions\64_hz\40kO.npy as .mat: Matlab\predictions\64_hz\40kO.mat
# Saving predictions\64_hz\5bSg.npy as .mat: Matlab\predictions\64_hz\5bSg.mat
# Saving predictions\64_hz\6iwd.npy as .mat: Matlab\predictions\64_hz\6iwd.mat
# Saving predictions\64_hz\6JVj.npy as .mat: Matlab\predictions\64_hz\6JVj.mat
# Saving predictions\64_hz\9098.npy as .mat: Matlab\predictions\64_hz\9098.mat
# Saving predictions\64_hz\9JQY.npy as .mat: Matlab\predictions\64_hz\9JQY.mat
# Saving predictions\64_hz\Af8a.npy as .mat: Matlab\predictions\64_hz\Af8a.mat
# Saving predictions\64_hz\AsLD.npy as .mat: Matlab\predictions\64_hz\AsLD.mat
# Saving predictions\64_hz\AXbm.npy as .mat: Matlab\predictions\64_hz\AXbm.mat
# Saving predictions\64_hz\bkx9.npy as .mat: Matlab\predictions\64_hz\bkx9.mat
# Saving predictions\64_hz\BSvO.npy as .mat: Matlab\predictions\64_hz\BSvO.mat
# Saving predictions\64_hz\C1Wu.npy as .mat: Matlab\predictions\64_hz\C1Wu.mat
# Saving predictions\64_hz\cblr.npy as .mat: Matlab\predictions\64_hz\cblr.mat
# Saving predictions\64_hz\csxQ.npy as .mat: Matlab\predictions\64_hz\csxQ.mat
# Saving predictions\64_hz\d3ET.npy as .mat: Matlab\predictions\64_hz\d3ET.mat
# Saving predictions\64_hz\ddTG.npy as .mat: Matlab\predictions\64_hz\ddTG.mat
# Saving predictions\64_hz\DjrT.npy as .mat: Matlab\predictions\64_hz\DjrT.mat
# Saving predictions\64_hz\Dr51.npy as .mat: Matlab\predictions\64_hz\Dr51.mat
# Saving predictions\64_hz\DSfb.npy as .mat: Matlab\predictions\64_hz\DSfb.mat
# Saving predictions\64_hz\DYYI.npy as .mat: Matlab\predictions\64_hz\DYYI.mat
# Saving predictions\64_hz\EHED.npy as .mat: Matlab\predictions\64_hz\EHED.mat
# Saving predictions\64_hz\EMcQ.npy as .mat: Matlab\predictions\64_hz\EMcQ.mat
# Saving predictions\64_hz\EyTS.npy as .mat: Matlab\predictions\64_hz\EyTS.mat
# Saving predictions\64_hz\f8H5.npy as .mat: Matlab\predictions\64_hz\f8H5.mat
# Saving predictions\64_hz\fNe4.npy as .mat: Matlab\predictions\64_hz\fNe4.mat
# Saving predictions\64_hz\fT68.npy as .mat: Matlab\predictions\64_hz\fT68.mat
# Saving predictions\64_hz\G7PJ.npy as .mat: Matlab\predictions\64_hz\G7PJ.mat
# Saving predictions\64_hz\go56.npy as .mat: Matlab\predictions\64_hz\go56.mat
# Saving predictions\64_hz\hcml.npy as .mat: Matlab\predictions\64_hz\hcml.mat
# Saving predictions\64_hz\hRMy.npy as .mat: Matlab\predictions\64_hz\hRMy.mat
# Saving predictions\64_hz\hT38.npy as .mat: Matlab\predictions\64_hz\hT38.mat
# Saving predictions\64_hz\ibbz.npy as .mat: Matlab\predictions\64_hz\ibbz.mat
# Saving predictions\64_hz\IhpU.npy as .mat: Matlab\predictions\64_hz\IhpU.mat
# Saving predictions\64_hz\ipxV.npy as .mat: Matlab\predictions\64_hz\ipxV.mat
# Saving predictions\64_hz\iSqw.npy as .mat: Matlab\predictions\64_hz\iSqw.mat
# Saving predictions\64_hz\Ivfn.npy as .mat: Matlab\predictions\64_hz\Ivfn.mat
# Saving predictions\64_hz\JCpz.npy as .mat: Matlab\predictions\64_hz\JCpz.mat
# Saving predictions\64_hz\kj2l.npy as .mat: Matlab\predictions\64_hz\kj2l.mat
# Saving predictions\64_hz\Kn9O.npy as .mat: Matlab\predictions\64_hz\Kn9O.mat
# Saving predictions\64_hz\LR2s.npy as .mat: Matlab\predictions\64_hz\LR2s.mat
# Saving predictions\64_hz\mBks.npy as .mat: Matlab\predictions\64_hz\mBks.mat
# Saving predictions\64_hz\MS6u.npy as .mat: Matlab\predictions\64_hz\MS6u.mat
# Saving predictions\64_hz\Msy4.npy as .mat: Matlab\predictions\64_hz\Msy4.mat
# Saving predictions\64_hz\muls.npy as .mat: Matlab\predictions\64_hz\muls.mat
# Saving predictions\64_hz\mZje.npy as .mat: Matlab\predictions\64_hz\mZje.mat
# Saving predictions\64_hz\N1nM.npy as .mat: Matlab\predictions\64_hz\N1nM.mat
# Saving predictions\64_hz\Nzhl.npy as .mat: Matlab\predictions\64_hz\Nzhl.mat
# Saving predictions\64_hz\oOMR.npy as .mat: Matlab\predictions\64_hz\oOMR.mat
# Saving predictions\64_hz\Otq3.npy as .mat: Matlab\predictions\64_hz\Otq3.mat
# Saving predictions\64_hz\pPpj.npy as .mat: Matlab\predictions\64_hz\pPpj.mat
# Saving predictions\64_hz\puoa.npy as .mat: Matlab\predictions\64_hz\puoa.mat
# Saving predictions\64_hz\QDsa.npy as .mat: Matlab\predictions\64_hz\QDsa.mat
# Saving predictions\64_hz\R2f3.npy as .mat: Matlab\predictions\64_hz\R2f3.mat
# Saving predictions\64_hz\RfL0.npy as .mat: Matlab\predictions\64_hz\RfL0.mat
# Saving predictions\64_hz\RM1S.npy as .mat: Matlab\predictions\64_hz\RM1S.mat
# Saving predictions\64_hz\sNMf.npy as .mat: Matlab\predictions\64_hz\sNMf.mat
# Saving predictions\64_hz\SOZ3.npy as .mat: Matlab\predictions\64_hz\SOZ3.mat
# Saving predictions\64_hz\svlu.npy as .mat: Matlab\predictions\64_hz\svlu.mat
# Saving predictions\64_hz\tG6i.npy as .mat: Matlab\predictions\64_hz\tG6i.mat
# Saving predictions\64_hz\UsSz.npy as .mat: Matlab\predictions\64_hz\UsSz.mat
# Saving predictions\64_hz\UwK6.npy as .mat: Matlab\predictions\64_hz\UwK6.mat
# Saving predictions\64_hz\uXdB.npy as .mat: Matlab\predictions\64_hz\uXdB.mat
# Saving predictions\64_hz\X7s0.npy as .mat: Matlab\predictions\64_hz\X7s0.mat
# Saving predictions\64_hz\Xg1l.npy as .mat: Matlab\predictions\64_hz\Xg1l.mat
# Saving predictions\64_hz\Xii6.npy as .mat: Matlab\predictions\64_hz\Xii6.mat
# Saving predictions\64_hz\Y4FK.npy as .mat: Matlab\predictions\64_hz\Y4FK.mat
# Saving predictions\64_hz\y5We.npy as .mat: Matlab\predictions\64_hz\y5We.mat
# Saving predictions\64_hz\YHLr.npy as .mat: Matlab\predictions\64_hz\YHLr.mat
# Saving predictions\64_hz\YOh8.npy as .mat: Matlab\predictions\64_hz\YOh8.mat
# Saving predictions\64_hz\zaca.npy as .mat: Matlab\predictions\64_hz\zaca.mat
# Saving predictions\64_hz\Zpwh.npy as .mat: Matlab\predictions\64_hz\Zpwh.mat
# Saving predictions\64_hz\ZYFG.npy as .mat: Matlab\predictions\64_hz\ZYFG.mat
# Saving predictions\8_hz\0ncr.npy as .mat: Matlab\predictions\8_hz\0ncr.mat
# Saving predictions\8_hz\0pai.npy as .mat: Matlab\predictions\8_hz\0pai.mat
# Saving predictions\8_hz\3J4W.npy as .mat: Matlab\predictions\8_hz\3J4W.mat
# Saving predictions\8_hz\3P0D.npy as .mat: Matlab\predictions\8_hz\3P0D.mat
# Saving predictions\8_hz\40kO.npy as .mat: Matlab\predictions\8_hz\40kO.mat
# Saving predictions\8_hz\5bSg.npy as .mat: Matlab\predictions\8_hz\5bSg.mat
# Saving predictions\8_hz\6iwd.npy as .mat: Matlab\predictions\8_hz\6iwd.mat
# Saving predictions\8_hz\6JVj.npy as .mat: Matlab\predictions\8_hz\6JVj.mat
# Saving predictions\8_hz\9098.npy as .mat: Matlab\predictions\8_hz\9098.mat
# Saving predictions\8_hz\9JQY.npy as .mat: Matlab\predictions\8_hz\9JQY.mat
# Saving predictions\8_hz\Af8a.npy as .mat: Matlab\predictions\8_hz\Af8a.mat
# Saving predictions\8_hz\AsLD.npy as .mat: Matlab\predictions\8_hz\AsLD.mat
# Saving predictions\8_hz\AXbm.npy as .mat: Matlab\predictions\8_hz\AXbm.mat
# Saving predictions\8_hz\bkx9.npy as .mat: Matlab\predictions\8_hz\bkx9.mat
# Saving predictions\8_hz\BSvO.npy as .mat: Matlab\predictions\8_hz\BSvO.mat
# Saving predictions\8_hz\C1Wu.npy as .mat: Matlab\predictions\8_hz\C1Wu.mat
# Saving predictions\8_hz\cblr.npy as .mat: Matlab\predictions\8_hz\cblr.mat
# Saving predictions\8_hz\csxQ.npy as .mat: Matlab\predictions\8_hz\csxQ.mat
# Saving predictions\8_hz\d3ET.npy as .mat: Matlab\predictions\8_hz\d3ET.mat
# Saving predictions\8_hz\ddTG.npy as .mat: Matlab\predictions\8_hz\ddTG.mat
# Saving predictions\8_hz\DjrT.npy as .mat: Matlab\predictions\8_hz\DjrT.mat
# Saving predictions\8_hz\Dr51.npy as .mat: Matlab\predictions\8_hz\Dr51.mat
# Saving predictions\8_hz\DSfb.npy as .mat: Matlab\predictions\8_hz\DSfb.mat
# Saving predictions\8_hz\DYYI.npy as .mat: Matlab\predictions\8_hz\DYYI.mat
# Saving predictions\8_hz\EHED.npy as .mat: Matlab\predictions\8_hz\EHED.mat
# Saving predictions\8_hz\EMcQ.npy as .mat: Matlab\predictions\8_hz\EMcQ.mat
# Saving predictions\8_hz\EyTS.npy as .mat: Matlab\predictions\8_hz\EyTS.mat
# Saving predictions\8_hz\f8H5.npy as .mat: Matlab\predictions\8_hz\f8H5.mat
# Saving predictions\8_hz\fNe4.npy as .mat: Matlab\predictions\8_hz\fNe4.mat
# Saving predictions\8_hz\fT68.npy as .mat: Matlab\predictions\8_hz\fT68.mat
# Saving predictions\8_hz\G7PJ.npy as .mat: Matlab\predictions\8_hz\G7PJ.mat
# Saving predictions\8_hz\go56.npy as .mat: Matlab\predictions\8_hz\go56.mat
# Saving predictions\8_hz\hcml.npy as .mat: Matlab\predictions\8_hz\hcml.mat
# Saving predictions\8_hz\hRMy.npy as .mat: Matlab\predictions\8_hz\hRMy.mat
# Saving predictions\8_hz\hT38.npy as .mat: Matlab\predictions\8_hz\hT38.mat
# Saving predictions\8_hz\ibbz.npy as .mat: Matlab\predictions\8_hz\ibbz.mat
# Saving predictions\8_hz\IhpU.npy as .mat: Matlab\predictions\8_hz\IhpU.mat
# Saving predictions\8_hz\ipxV.npy as .mat: Matlab\predictions\8_hz\ipxV.mat
# Saving predictions\8_hz\iSqw.npy as .mat: Matlab\predictions\8_hz\iSqw.mat
# Saving predictions\8_hz\Ivfn.npy as .mat: Matlab\predictions\8_hz\Ivfn.mat
# Saving predictions\8_hz\JCpz.npy as .mat: Matlab\predictions\8_hz\JCpz.mat
# Saving predictions\8_hz\kj2l.npy as .mat: Matlab\predictions\8_hz\kj2l.mat
# Saving predictions\8_hz\Kn9O.npy as .mat: Matlab\predictions\8_hz\Kn9O.mat
# Saving predictions\8_hz\LR2s.npy as .mat: Matlab\predictions\8_hz\LR2s.mat
# Saving predictions\8_hz\mBks.npy as .mat: Matlab\predictions\8_hz\mBks.mat
# Saving predictions\8_hz\MS6u.npy as .mat: Matlab\predictions\8_hz\MS6u.mat
# Saving predictions\8_hz\Msy4.npy as .mat: Matlab\predictions\8_hz\Msy4.mat
# Saving predictions\8_hz\muls.npy as .mat: Matlab\predictions\8_hz\muls.mat
# Saving predictions\8_hz\mZje.npy as .mat: Matlab\predictions\8_hz\mZje.mat
# Saving predictions\8_hz\N1nM.npy as .mat: Matlab\predictions\8_hz\N1nM.mat
# Saving predictions\8_hz\Nzhl.npy as .mat: Matlab\predictions\8_hz\Nzhl.mat
# Saving predictions\8_hz\oOMR.npy as .mat: Matlab\predictions\8_hz\oOMR.mat
# Saving predictions\8_hz\Otq3.npy as .mat: Matlab\predictions\8_hz\Otq3.mat
# Saving predictions\8_hz\pPpj.npy as .mat: Matlab\predictions\8_hz\pPpj.mat
# Saving predictions\8_hz\puoa.npy as .mat: Matlab\predictions\8_hz\puoa.mat
# Saving predictions\8_hz\QDsa.npy as .mat: Matlab\predictions\8_hz\QDsa.mat
# Saving predictions\8_hz\R2f3.npy as .mat: Matlab\predictions\8_hz\R2f3.mat
# Saving predictions\8_hz\RfL0.npy as .mat: Matlab\predictions\8_hz\RfL0.mat
# Saving predictions\8_hz\RM1S.npy as .mat: Matlab\predictions\8_hz\RM1S.mat
# Saving predictions\8_hz\sNMf.npy as .mat: Matlab\predictions\8_hz\sNMf.mat
# Saving predictions\8_hz\SOZ3.npy as .mat: Matlab\predictions\8_hz\SOZ3.mat
# Saving predictions\8_hz\svlu.npy as .mat: Matlab\predictions\8_hz\svlu.mat
# Saving predictions\8_hz\tG6i.npy as .mat: Matlab\predictions\8_hz\tG6i.mat
# Saving predictions\8_hz\UsSz.npy as .mat: Matlab\predictions\8_hz\UsSz.mat
# Saving predictions\8_hz\UwK6.npy as .mat: Matlab\predictions\8_hz\UwK6.mat
# Saving predictions\8_hz\uXdB.npy as .mat: Matlab\predictions\8_hz\uXdB.mat
# Saving predictions\8_hz\X7s0.npy as .mat: Matlab\predictions\8_hz\X7s0.mat
# Saving predictions\8_hz\Xg1l.npy as .mat: Matlab\predictions\8_hz\Xg1l.mat
# Saving predictions\8_hz\Xii6.npy as .mat: Matlab\predictions\8_hz\Xii6.mat
# Saving predictions\8_hz\Y4FK.npy as .mat: Matlab\predictions\8_hz\Y4FK.mat
# Saving predictions\8_hz\y5We.npy as .mat: Matlab\predictions\8_hz\y5We.mat
# Saving predictions\8_hz\YHLr.npy as .mat: Matlab\predictions\8_hz\YHLr.mat
# Saving predictions\8_hz\YOh8.npy as .mat: Matlab\predictions\8_hz\YOh8.mat
# Saving predictions\8_hz\zaca.npy as .mat: Matlab\predictions\8_hz\zaca.mat
# Saving predictions\8_hz\Zpwh.npy as .mat: Matlab\predictions\8_hz\Zpwh.mat
# Saving predictions\8_hz\ZYFG.npy as .mat: Matlab\predictions\8_hz\ZYFG.mat

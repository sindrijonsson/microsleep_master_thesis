# %% [markdown]
# # Self-supervised Learning for microsleep detection
#
# Authors: Sindri Jónsson
#
# Adapted from https://braindecode.org/stable/auto_examples/plot_relative_positioning.html#id5

# %%
# Initiliaze 

random_state = 87
n_jobs = 1

# %% [markdown]
# ## Setup
# 1. Load datasets
# 2. Pre-process and windowing
# 3. Split data into train, validation and test sets

# %% [markdown]
# ### Load datasets

# %%
# Load dataset 

import mne
import glob
from braindecode.datasets import BaseDataset, BaseConcatDataset
from IPython.display import clear_output

ds = []

channel_combs = [
    ("O1-M2", "E1-M1"),
    ("O1-M2", "E2-M1"),
    ("O2-M1", "E1-M1"),
    ("O2-M1", "E2-M1")
                ]

for path in glob.glob("SSL_data/*.edf"):

    for ch in channel_combs:

        # Read edf and add annotations
        file=mne.io.read_raw_edf(path)
    
        # Create one dataset for each channel combination (averaged across channel combinations in test predictions)
        drop_channels = [x for x in file.ch_names if x not in ch]
        file.drop_channels(drop_channels)
        
        subj = path.split("\\")[-1].replace(".edf","")
        ch_names = "_".join(ch)
        ds.append(BaseDataset(file, description={"subject": subj+"@"+ch_names}))
        clear_output()
        
    
ds = BaseConcatDataset(ds)

# %% [markdown]
# ### Pre-process (re-sample)

# %%
# Pre-process signals: resample to 100 Hz
from braindecode.preprocessing.preprocess import preprocess, Preprocessor

# #Pre process data
signal_samp_freq = 100
pp = [Preprocessor("resample", sfreq=signal_samp_freq)]

preprocess(ds, pp)

# %% [markdown]
# ### Windowing

# %%
# Create window dataset

print("creating windows")

from braindecode.preprocessing import create_fixed_length_windows

# Extract windows
win_sec = 15       # Window length (sec)
step_sec = 1       # Step size (sec)
win_samp = int(win_sec * signal_samp_freq)
step_samp = int(step_sec * signal_samp_freq)


windows_dataset = create_fixed_length_windows(ds, window_size_samples=win_samp, window_stride_samples=step_samp,
                                  drop_last_window=True, preload=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 13
#       9 win_samp = int(win_sec * signal_samp_freq)
#      10 step_samp = int(step_sec * signal_samp_freq)
# ---> 13 windows_dataset = create_fixed_length_windows(ds, window_size_samples=win_samp, window_stride_samples=step_samp,
#      14                                   drop_last_window=True, preload=True)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\braindecode\preprocessing\windowers.py:202, in create_fixed_length_windows(concat_ds, start_offset_samples, stop_offset_samples, window_size_samples, window_stride_samples, drop_last_window, mapping, preload, drop_bad_windows, picks, reject, flat, targets_from, last_target_only, on_missing, n_jobs, verbose)
#     198 if any(window_size_samples > lengths):
#     199     raise ValueError(f'Window size {window_size_samples} exceeds trial '
#     200                      f'duration {lengths.min()}.')
# --> 202 list_of_windows_ds = Parallel(n_jobs=n_jobs)(
#     203     delayed(_create_fixed_length_windows)(
#     204         ds, start_offset_samples, stop_offset_samples, window_size_samples,
#     205         window_stride_samples, drop_last_window, mapping, preload,
#     206         drop_bad_windows, picks, reject, flat, targets_from, last_target_only,
#     207         on_missing, verbose) for ds in concat_ds.datasets)
#     209 return BaseConcatDataset(list_of_windows_ds)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\braindecode\preprocessing\windowers.py:391, in _create_fixed_length_windows(ds, start_offset_samples, stop_offset_samples, window_size_samples, window_stride_samples, drop_last_window, mapping, preload, drop_bad_windows, picks, reject, flat, targets_from, last_target_only, on_missing, verbose)
#     383 metadata = pd.DataFrame({
#     384     'i_window_in_trial': np.arange(len(fake_events)),
#     385     'i_start_in_trial': starts,
#     386     'i_stop_in_trial': starts + window_size_samples,
#     387     'target': len(fake_events) * [target]
#     388 })
#     390 # window size - 1, since tmax is inclusive
# --> 391 mne_epochs = mne.Epochs(
#     392     ds.raw, fake_events, baseline=None, tmin=0,
#     393     tmax=(window_size_samples - 1) / ds.raw.info['sfreq'],
#     394     metadata=metadata, preload=preload, picks=picks, reject=reject,
#     395     flat=flat, on_missing=on_missing, verbose=verbose)
#     397 if drop_bad_windows:
#     398     mne_epochs.drop_bad()
#
# File <decorator-gen-280>:10, in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\epochs.py:2635, in Epochs.__init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#    2632 raw_sfreq = raw.info['sfreq']
#    2634 # call BaseEpochs constructor
# -> 2635 super(Epochs, self).__init__(
#    2636     info, None, events, event_id, tmin, tmax,
#    2637     metadata=metadata, baseline=baseline, raw=raw, picks=picks,
#    2638     reject=reject, flat=flat, decim=decim, reject_tmin=reject_tmin,
#    2639     reject_tmax=reject_tmax, detrend=detrend,
#    2640     proj=proj, on_missing=on_missing, preload_at_end=preload,
#    2641     event_repeated=event_repeated, verbose=verbose,
#    2642     raw_sfreq=raw_sfreq, annotations=raw.annotations)
#
# File <decorator-gen-266>:10, in __init__(self, info, data, events, event_id, tmin, tmax, baseline, raw, picks, reject, flat, decim, reject_tmin, reject_tmax, detrend, proj, on_missing, preload_at_end, selection, drop_log, filename, metadata, event_repeated, verbose, raw_sfreq, annotations)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\epochs.py:596, in BaseEpochs.__init__(***failed resolving arguments***)
#     594     assert self._data is None
#     595     assert self.preload is False
# --> 596     self.load_data()  # this will do the projection
#     597 elif proj is True and self._projector is not None and data is not None:
#     598     # let's make sure we project if data was provided and proj
#     599     # requested
#     600     # we could do this with np.einsum, but iteration should be
#     601     # more memory safe in most instances
#     602     for ii, epoch in enumerate(self._data):
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\epochs.py:653, in BaseEpochs.load_data(self)
#     651 if self.preload:
#     652     return self
# --> 653 self._data = self._get_data()
#     654 self.preload = True
#     655 self._do_baseline = False
#
# File <decorator-gen-272>:12, in _get_data(self, out, picks, item, units, tmin, tmax, verbose)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\epochs.py:1421, in BaseEpochs._get_data(self, out, picks, item, units, tmin, tmax, verbose)
#    1419         epoch = self._data[idx]
#    1420 else:  # from disk
# -> 1421     epoch_noproj = self._get_epoch_from_raw(idx)
#    1422     epoch_noproj = self._detrend_offset_decim(
#    1423         epoch_noproj, detrend_picks)
#    1424     epoch = self._project_epoch(epoch_noproj)
#
# File <decorator-gen-281>:12, in _get_epoch_from_raw(self, idx, verbose)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\epochs.py:2683, in Epochs._get_epoch_from_raw(self, idx, verbose)
#    2680 reject_stop = stop - diff
#    2682 logger.debug('    Getting epoch for %d-%d' % (start, stop))
# -> 2683 data = self._raw._check_bad_segment(start, stop, self.picks,
#    2684                                     reject_start, reject_stop,
#    2685                                     self.reject_by_annotation)
#    2686 return data
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py:474, in BaseRaw._check_bad_segment(self, start, stop, picks, reject_start, reject_stop, reject_by_annotation)
#     472         if descr.lower().startswith('bad'):
#     473             return descr
# --> 474 return self._getitem((picks, slice(start, stop)), return_times=False)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py:755, in BaseRaw._getitem(self, item, return_times)
#     753     data = self._data[sel, start:stop]
#     754 else:
# --> 755     data = self._read_segment(start=start, stop=stop, sel=sel,
#     756                               projector=self._projector)
#     758 if return_times:
#     759     # Rather than compute the entire thing just compute the subset
#     760     # times = self.times[start:stop]
#     761     # stop can be None here so don't use it directly
#     762     times = np.arange(start, start + data.shape[1], dtype=float)
#
# File <decorator-gen-226>:12, in _read_segment(self, start, stop, sel, data_buffer, projector, verbose)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py:392, in BaseRaw._read_segment(***failed resolving arguments***)
#     390     # reindex back to original file
#     391     orig_idx = _convert_slice(self._read_picks[fi][need_idx])
# --> 392     _ReadSegmentFileProtector(self)._read_segment_file(
#     393         data[:, this_sl], orig_idx, fi,
#     394         int(start_file), int(stop_file), cals, mult)
#     395     offset += n_read
#     396 return data
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py:2140, in _ReadSegmentFileProtector._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#    2139 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
# -> 2140     return self.__raw.__class__._read_segment_file(
#    2141         self, data, idx, fi, start, stop, cals, mult)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\edf\edf.py:191, in RawEDF._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#     189 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
#     190     """Read a chunk of raw data."""
# --> 191     return _read_segment_file(data, idx, fi, start, stop,
#     192                               self._raw_extras[fi], self._filenames[fi],
#     193                               cals, mult)
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\edf\edf.py:335, in _read_segment_file(data, idx, fi, start, stop, raw_extras, filenames, cals, mult)
#     333 fid.seek(start_offset + block_offset, 0)
#     334 # Read and reshape to (n_chunks_read, ch0_ch1_ch2_ch3...)
# --> 335 many_chunk = _read_ch(fid, subtype, ch_offsets[-1] * n_read,
#     336                       dtype_byte, dtype).reshape(n_read, -1)
#     337 r_sidx = r_lims[ai][0]
#     338 r_eidx = (buf_len * (n_read - 1) + r_lims[ai + n_read - 1][1])
#
# File c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\edf\edf.py:288, in _read_ch(fid, subtype, samp, dtype_byte, dtype)
#     284     ch_data[ch_data >= (1 << 23)] -= (1 << 24)
#     286 # GDF data and EDF data
#     287 else:
# --> 288     ch_data = np.fromfile(fid, dtype=dtype, count=samp)
#     290 return ch_data
#
# KeyboardInterrupt:

# %%
# Add target labels (MS) to window datset
from scipy.io import loadmat
import numpy as np

for w in windows_dataset.datasets:
    filename = f"edf_data/{w.description['subject']}_status.mat"
    filename = filename.replace("SSL_data","")
    filename = filename.split("@")[0] + "_status.mat"
    mat = loadmat(filename, squeeze_me=True)
    y = mat['x']
    y[np.isnan(y)] = -1
    w.y = y
    w.windows.metadata["target"] = w.y

# %% [markdown]
# ### Pre-process (standardize)

# %%
# Pre-process windows: standardize windows channel-wise
from sklearn.preprocessing import scale as standard_scale
print("Pre-processing")
preprocess(windows_dataset, [Preprocessor(standard_scale, channel_wise=True)])
# Out:
# Pre-processing

# %% [markdown]
# ### Split data

# %%
# Split the data to train, validation and test splits
import json
from braindecode.datasets import BaseConcatDataset

with open("splits/skorucack_splits_with_validation.json") as f:
    splits = json.load(f)


# Splitting dataset into train, valid and test sets
subj_train = splits['train']
subj_valid = splits["valid"]
subj_test = splits["test"]

class RelativePositioningDataset(BaseConcatDataset):
    """BaseConcatDataset with __getitem__ that expects 2 indices and a target.
    """
    def __init__(self, list_of_ds):
        super().__init__(list_of_ds)
        self.return_pair = True

    def __getitem__(self, index):
        if self.return_pair:
            ind1, ind2, y = index
            return (super().__getitem__(ind1)[0],
                    super().__getitem__(ind2)[0]), y
        else:
            return super().__getitem__(index)

    @property
    def return_pair(self):
        return self._return_pair

    @return_pair.setter
    def return_pair(self, value):
        self._return_pair = value



split_ids = {'train': subj_train, 'valid': subj_valid, 'test': subj_test}
splitted = dict()
for name, values in split_ids.items():
    splitted[name] = RelativePositioningDataset(
        [ds for ds in windows_dataset.datasets
        if ds.description['subject'].split("@")[0] in values])

# %% [markdown]
# ## Pretext Task - Relative Positioning (RP)
# 1. Create RP samplers
# 2. Create and train embedder model
# 3. Plot training curves
# 4. Test embedder on RP task

# %% [markdown]
# ### Create samplers

# %%
# Create samplers for relative positioning task

from braindecode.samplers import RelativePositioningSampler
n = 800
tau_pos = int(signal_samp_freq * 30)
tau_neg = int(signal_samp_freq * 3 * 60)

n_examples_train = n * len(splitted['train'].datasets)
n_examples_valid = n * len(splitted['valid'].datasets)
n_examples_test = n * len(splitted['test'].datasets)

train_sampler = RelativePositioningSampler(
    splitted['train'].get_metadata(), tau_pos=tau_pos, tau_neg=tau_neg,
    n_examples=n_examples_train, same_rec_neg=True, random_state=random_state)
valid_sampler = RelativePositioningSampler(
    splitted['valid'].get_metadata(), tau_pos=tau_pos, tau_neg=tau_neg,
    n_examples=n_examples_valid, same_rec_neg=True,
    random_state=random_state).presample()
test_sampler = RelativePositioningSampler(
    splitted['test'].get_metadata(), tau_pos=tau_pos, tau_neg=tau_neg,
    n_examples=n_examples_test, same_rec_neg=True,
    random_state=random_state).presample()

# %% [markdown]
# ### Create and train embedder

# %%
# Create model for RP task
import torch
from torch import nn
from braindecode.util import set_random_seeds
from braindecode.models import SleepStagerChambon2018

# Creating the model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device == 'cuda':
    torch.backends.cudnn.benchmark = True
# Set random seed to be able to roughly reproduce results
# Note that with cudnn benchmark set to True, GPU indeterminism
# may still make results substantially different between runs.
# To obtain more consistent results at the cost of increased computation time,
# you can set `cudnn_benchmark=False` in `set_random_seeds`
# or remove `torch.backends.cudnn.benchmark = True`
set_random_seeds(seed=random_state, cuda=device == 'cuda')

# Extract number of channels and time steps from dataset
n_channels, input_size_samples = windows_dataset[0][0].shape
emb_size = 100
tcs = 0.25

emb = SleepStagerChambon2018(
    n_channels,
    signal_samp_freq,
    n_classes=emb_size,
    n_conv_chs=16,
    time_conv_size_s=tcs,
    max_pool_size_s=tcs/4,
    input_size_s=input_size_samples / signal_samp_freq,
    dropout=0,
    pad_size_s=tcs/2,
    apply_batch_norm=True
)


class ContrastiveNet(nn.Module):
    """Contrastive module with linear layer on top of siamese embedder.

    Parameters
    ----------
    emb : nn.Module
        Embedder architecture.
    emb_size : int
        Output size of the embedder.
    dropout : float
        Dropout rate applied to the linear layer of the contrastive module.
    """
    def __init__(self, emb, emb_size, dropout=0.5):
        super().__init__()
        self.emb = emb
        self.clf = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(emb_size, 1)
        )

    def forward(self, x):
        x1, x2 = x
        z1, z2 = self.emb(x1), self.emb(x2)
        return self.clf(torch.abs(z1 - z2)).flatten()


model = ContrastiveNet(emb, emb_size, dropout=0.3).to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [20], line 20
#      17 set_random_seeds(seed=random_state, cuda=device == 'cuda')
#      19 # Extract number of channels and time steps from dataset
# ---> 20 n_channels, input_size_samples = windows_dataset[0][0].shape
#      21 emb_size = 100
#      22 tcs = 0.25
#
# NameError: name 'windows_dataset' is not defined

# %%
# Train RP model

import os
from datetime import date
from skorch.helper import predefined_split
from skorch.callbacks import Checkpoint, EarlyStopping, EpochScoring
from braindecode import EEGClassifier

lr = 5e-3
batch_size = 256  # 512 if data large enough
n_epochs = 50
num_workers = 0 if n_jobs <= 1 else n_jobs

cp = Checkpoint(dirname='', f_criterion=None, f_optimizer=None, f_history=None)
early_stopping = EarlyStopping(patience=10)
train_acc = EpochScoring(
    scoring='accuracy', on_train=True, name='train_acc', lower_is_better=False)
valid_acc = EpochScoring(
    scoring='accuracy', on_train=False, name='valid_acc',
    lower_is_better=False)
callbacks = [
    ('cp', cp),
    ('patience', early_stopping),
    ('train_acc', train_acc),
    ('valid_acc', valid_acc)
]

clf = EEGClassifier(
    model,
    criterion=torch.nn.BCEWithLogitsLoss,
    optimizer=torch.optim.Adam,
    max_epochs=n_epochs,
    iterator_train__shuffle=False,
    iterator_train__sampler=train_sampler,
    iterator_valid__sampler=valid_sampler,
    iterator_train__num_workers=num_workers,
    iterator_valid__num_workers=num_workers,
    train_split=predefined_split(splitted['valid']),
    optimizer__lr=lr,
    batch_size=batch_size,
    callbacks=callbacks,
    device=device
)


train_model = False
 
if train_model:
    today = date.today().strftime("%d%m%Y")
    folder = f"SSL_{today}"
    os.mkdir(folder)
# Model training for a specified number of epochs. `y` is None as it is already
# supplied in the dataset.
    clf.fit(splitted['train'], y=None)
    clf.load_params(checkpoint=cp)  # Load the model with the lowest valid_loss
    clf.save_params(f_params=f"{folder}\\model.pkl",
        f_optimizer=f"{folder}\\optimizer.pkl",
        f_history=f"{folder}\\history.json")
    os.remove("params.pt")
else:
    # Load
    load_folder = "SSL_08022023"
    clf.initialize()
    clf.load_params(f_params=f"{load_folder}\\model.pkl",
            f_optimizer=f"{load_folder}\\optimizer.pkl",
            f_history=f"{load_folder}\\history.json")

# %% [markdown]
# ### Plot training curves

# %%
# Plot RP training curves


import matplotlib.pyplot as plt
import pandas as pd

# Extract loss and balanced accuracy values for plotting from history object
df = pd.DataFrame(clf.history.to_list())

df['train_acc'] *= 100
df['valid_acc'] *= 100

ys1 = ['train_loss', 'valid_loss']
ys2 = ['train_acc', 'valid_acc']
styles = ['-', ':']
markers = ['.', '.']

plt.style.use('seaborn-talk')

fig, ax1 = plt.subplots(figsize=(8, 5))
ax2 = ax1.twinx()
for y1, y2, style, marker in zip(ys1, ys2, styles, markers):
    ax1.plot(df['epoch'], df[y1], ls=style, marker=marker, ms=7,
             c='tab:blue', label=y1)
    ax2.plot(df['epoch'], df[y2], ls=style, marker=marker, ms=7,
             c='tab:orange', label=y2)

ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylabel('Loss', color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:orange')
ax2.set_ylabel('Accuracy [%]', color='tab:orange')
ax1.set_xlabel('Epoch')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test results in RP task

# %%
# Test results of RP task
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Switch to the test sampler
clf.iterator_valid__sampler = test_sampler
y_pred = clf.forward(splitted['test'], training=False) > 0
y_true = [y for _, _, y in test_sampler]

print("RP test data")
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# RP test data
# [[27495  9243]
#  [ 8767 28095]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.75      0.75     36738
#          1.0       0.75      0.76      0.76     36862
#
#     accuracy                           0.76     73600
#    macro avg       0.76      0.76      0.76     73600
# weighted avg       0.76      0.76      0.76     73600

# %% [markdown]
# ## Downstream task
# 1. Generate features using embedder
# 2. Train logistic regression classifier (channel wise)
# 3. Optimal thresholding
# 4. Test predictions

# %% [markdown]
# ### Generate features using embedder

# %%
# Generate features from the embedder for the train, validation and test splits
from torch.utils.data import DataLoader

# Extract features with the trained embedder
data = dict()
for name, split in splitted.items():
    print(name)
    split.return_pair = False  # Return single windows
    loader = DataLoader(split, batch_size=batch_size, num_workers=num_workers)
    i = 0
    with torch.no_grad():
        feats = []
        for batch_x, _, _ in loader:
            f=emb(batch_x.to(device)).cpu().numpy()
            feats.append(f)
            prc = i/(len(loader)-1)*100
            print(f"{name}: {prc:.2f}%", flush=True)
            i += 1
    data[name] = (np.concatenate(feats), split.get_metadata()['target'].values)
# Out:
# train
# train: 0.00%
# train: 0.07%
# train: 0.14%
# train: 0.21%
# train: 0.29%
# train: 0.36%
# train: 0.43%
# train: 0.50%
# train: 0.57%
# train: 0.64%
# train: 0.71%
# train: 0.79%
# train: 0.86%
# train: 0.93%
# train: 1.00%
# train: 1.07%
# train: 1.14%
# train: 1.21%
# train: 1.29%
# train: 1.36%
# train: 1.43%
# train: 1.50%
# train: 1.57%
# train: 1.64%
# train: 1.71%
# train: 1.79%
# train: 1.86%
# train: 1.93%
# train: 2.00%
# train: 2.07%
# train: 2.14%
# train: 2.21%
# train: 2.29%
# train: 2.36%
# train: 2.43%
# train: 2.50%
# train: 2.57%
# train: 2.64%
# train: 2.71%
# train: 2.79%
# train: 2.86%
# train: 2.93%
# train: 3.00%
# train: 3.07%
# train: 3.14%
# train: 3.21%
# train: 3.29%
# train: 3.36%
# train: 3.43%
# train: 3.50%
# train: 3.57%
# train: 3.64%
# train: 3.71%
# train: 3.79%
# train: 3.86%
# train: 3.93%
# train: 4.00%
# train: 4.07%
# train: 4.14%
# train: 4.21%
# train: 4.29%
# train: 4.36%
# train: 4.43%
# train: 4.50%
# train: 4.57%
# train: 4.64%
# train: 4.71%
# train: 4.79%
# train: 4.86%
# train: 4.93%
# train: 5.00%
# train: 5.07%
# train: 5.14%
# train: 5.21%
# train: 5.29%
# train: 5.36%
# train: 5.43%
# train: 5.50%
# train: 5.57%
# train: 5.64%
# train: 5.71%
# train: 5.79%
# train: 5.86%
# train: 5.93%
# train: 6.00%
# train: 6.07%
# train: 6.14%
# train: 6.21%
# train: 6.29%
# train: 6.36%
# train: 6.43%
# train: 6.50%
# train: 6.57%
# train: 6.64%
# train: 6.71%
# train: 6.79%
# train: 6.86%
# train: 6.93%
# train: 7.00%
# train: 7.07%
# train: 7.14%
# train: 7.21%
# train: 7.29%
# train: 7.36%
# train: 7.43%
# train: 7.50%
# train: 7.57%
# train: 7.64%
# train: 7.71%
# train: 7.79%
# train: 7.86%
# train: 7.93%
# train: 8.00%
# train: 8.07%
# train: 8.14%
# train: 8.21%
# train: 8.29%
# train: 8.36%
# train: 8.43%
# train: 8.50%
# train: 8.57%
# train: 8.64%
# train: 8.71%
# train: 8.79%
# train: 8.86%
# train: 8.93%
# train: 9.00%
# train: 9.07%
# train: 9.14%
# train: 9.21%
# train: 9.29%
# train: 9.36%
# train: 9.43%
# train: 9.50%
# train: 9.57%
# train: 9.64%
# train: 9.71%
# train: 9.79%
# train: 9.86%
# train: 9.93%
# train: 10.00%
# train: 10.07%
# train: 10.14%
# train: 10.21%
# train: 10.29%
# train: 10.36%
# train: 10.43%
# train: 10.50%
# train: 10.57%
# train: 10.64%
# train: 10.71%
# train: 10.79%
# train: 10.86%
# train: 10.93%
# train: 11.00%
# train: 11.07%
# train: 11.14%
# train: 11.21%
# train: 11.29%
# train: 11.36%
# train: 11.43%
# train: 11.50%
# train: 11.57%
# train: 11.64%
# train: 11.71%
# train: 11.79%
# train: 11.86%
# train: 11.93%
# train: 12.00%
# train: 12.07%
# train: 12.14%
# train: 12.21%
# train: 12.29%
# train: 12.36%
# train: 12.43%
# train: 12.50%
# train: 12.57%
# train: 12.64%
# train: 12.71%
# train: 12.79%
# train: 12.86%
# train: 12.93%
# train: 13.00%
# train: 13.07%
# train: 13.14%
# train: 13.21%
# train: 13.29%
# train: 13.36%
# train: 13.43%
# train: 13.50%
# train: 13.57%
# train: 13.64%
# train: 13.71%
# train: 13.79%
# train: 13.86%
# train: 13.93%
# train: 14.00%
# train: 14.07%
# train: 14.14%
# train: 14.21%
# train: 14.29%
# train: 14.36%
# train: 14.43%
# train: 14.50%
# train: 14.57%
# train: 14.64%
# train: 14.71%
# train: 14.79%
# train: 14.86%
# train: 14.93%
# train: 15.00%
# train: 15.07%
# train: 15.14%
# train: 15.21%
# train: 15.29%
# train: 15.36%
# train: 15.43%
# train: 15.50%
# train: 15.57%
# train: 15.64%
# train: 15.71%
# train: 15.79%
# train: 15.86%
# train: 15.93%
# train: 16.00%
# train: 16.07%
# train: 16.14%
# train: 16.21%
# train: 16.29%
# train: 16.36%
# train: 16.43%
# train: 16.50%
# train: 16.57%
# train: 16.64%
# train: 16.71%
# train: 16.79%
# train: 16.86%
# train: 16.93%
# train: 17.00%
# train: 17.07%
# train: 17.14%
# train: 17.21%
# train: 17.29%
# train: 17.36%
# train: 17.43%
# train: 17.50%
# train: 17.57%
# train: 17.64%
# train: 17.71%
# train: 17.79%
# train: 17.86%
# train: 17.93%
# train: 18.00%
# train: 18.07%
# train: 18.14%
# train: 18.21%
# train: 18.29%
# train: 18.36%
# train: 18.43%
# train: 18.50%
# train: 18.57%
# train: 18.64%
# train: 18.71%
# train: 18.79%
# train: 18.86%
# train: 18.93%
# train: 19.00%
# train: 19.07%
# train: 19.14%
# train: 19.21%
# train: 19.29%
# train: 19.36%
# train: 19.43%
# train: 19.50%
# train: 19.57%
# train: 19.64%
# train: 19.71%
# train: 19.79%
# train: 19.86%
# train: 19.93%
# train: 20.00%
# train: 20.07%
# train: 20.14%
# train: 20.21%
# train: 20.29%
# train: 20.36%
# train: 20.43%
# train: 20.50%
# train: 20.57%
# train: 20.64%
# train: 20.71%
# train: 20.79%
# train: 20.86%
# train: 20.93%
# train: 21.00%
# train: 21.07%
# train: 21.14%
# train: 21.21%
# train: 21.29%
# train: 21.36%
# train: 21.43%
# train: 21.50%
# train: 21.57%
# train: 21.64%
# train: 21.71%
# train: 21.79%
# train: 21.86%
# train: 21.93%
# train: 22.00%
# train: 22.07%
# train: 22.14%
# train: 22.21%
# train: 22.29%
# train: 22.36%
# train: 22.43%
# train: 22.50%
# train: 22.57%
# train: 22.64%
# train: 22.71%
# train: 22.79%
# train: 22.86%
# train: 22.93%
# train: 23.00%
# train: 23.07%
# train: 23.14%
# train: 23.21%
# train: 23.29%
# train: 23.36%
# train: 23.43%
# train: 23.50%
# train: 23.57%
# train: 23.64%
# train: 23.71%
# train: 23.79%
# train: 23.86%
# train: 23.93%
# train: 24.00%
# train: 24.07%
# train: 24.14%
# train: 24.21%
# train: 24.29%
# train: 24.36%
# train: 24.43%
# train: 24.50%
# train: 24.57%
# train: 24.64%
# train: 24.71%
# train: 24.79%
# train: 24.86%
# train: 24.93%
# train: 25.00%
# train: 25.07%
# train: 25.14%
# train: 25.21%
# train: 25.29%
# train: 25.36%
# train: 25.43%
# train: 25.50%
# train: 25.57%
# train: 25.64%
# train: 25.71%
# train: 25.79%
# train: 25.86%
# train: 25.93%
# train: 26.00%
# train: 26.07%
# train: 26.14%
# train: 26.21%
# train: 26.29%
# train: 26.36%
# train: 26.43%
# train: 26.50%
# train: 26.57%
# train: 26.64%
# train: 26.71%
# train: 26.79%
# train: 26.86%
# train: 26.93%
# train: 27.00%
# train: 27.07%
# train: 27.14%
# train: 27.21%
# train: 27.29%
# train: 27.36%
# train: 27.43%
# train: 27.50%
# train: 27.57%
# train: 27.64%
# train: 27.71%
# train: 27.79%
# train: 27.86%
# train: 27.93%
# train: 28.00%
# train: 28.07%
# train: 28.14%
# train: 28.21%
# train: 28.29%
# train: 28.36%
# train: 28.43%
# train: 28.50%
# train: 28.57%
# train: 28.64%
# train: 28.71%
# train: 28.79%
# train: 28.86%
# train: 28.93%
# train: 29.00%
# train: 29.07%
# train: 29.14%
# train: 29.21%
# train: 29.29%
# train: 29.36%
# train: 29.43%
# train: 29.50%
# train: 29.57%
# train: 29.64%
# train: 29.71%
# train: 29.79%
# train: 29.86%
# train: 29.93%
# train: 30.00%
# train: 30.07%
# train: 30.14%
# train: 30.21%
# train: 30.29%
# train: 30.36%
# train: 30.43%
# train: 30.50%
# train: 30.57%
# train: 30.64%
# train: 30.71%
# train: 30.79%
# train: 30.86%
# train: 30.93%
# train: 31.00%
# train: 31.07%
# train: 31.14%
# train: 31.21%
# train: 31.29%
# train: 31.36%
# train: 31.43%
# train: 31.50%
# train: 31.57%
# train: 31.64%
# train: 31.71%
# train: 31.79%
# train: 31.86%
# train: 31.93%
# train: 32.00%
# train: 32.07%
# train: 32.14%
# train: 32.21%
# train: 32.29%
# train: 32.36%
# train: 32.43%
# train: 32.50%
# train: 32.57%
# train: 32.64%
# train: 32.71%
# train: 32.79%
# train: 32.86%
# train: 32.93%
# train: 33.00%
# train: 33.07%
# train: 33.14%
# train: 33.21%
# train: 33.29%
# train: 33.36%
# train: 33.43%
# train: 33.50%
# train: 33.57%
# train: 33.64%
# train: 33.71%
# train: 33.79%
# train: 33.86%
# train: 33.93%
# train: 34.00%
# train: 34.07%
# train: 34.14%
# train: 34.21%
# train: 34.29%
# train: 34.36%
# train: 34.43%
# train: 34.50%
# train: 34.57%
# train: 34.64%
# train: 34.71%
# train: 34.79%
# train: 34.86%
# train: 34.93%
# train: 35.00%
# train: 35.07%
# train: 35.14%
# train: 35.21%
# train: 35.29%
# train: 35.36%
# train: 35.43%
# train: 35.50%
# train: 35.57%
# train: 35.64%
# train: 35.71%
# train: 35.79%
# train: 35.86%
# train: 35.93%
# train: 36.00%
# train: 36.07%
# train: 36.14%
# train: 36.21%
# train: 36.29%
# train: 36.36%
# train: 36.43%
# train: 36.50%
# train: 36.57%
# train: 36.64%
# train: 36.71%
# train: 36.79%
# train: 36.86%
# train: 36.93%
# train: 37.00%
# train: 37.07%
# train: 37.14%
# train: 37.21%
# train: 37.29%
# train: 37.36%
# train: 37.43%
# train: 37.50%
# train: 37.57%
# train: 37.64%
# train: 37.71%
# train: 37.79%
# train: 37.86%
# train: 37.93%
# train: 38.00%
# train: 38.07%
# train: 38.14%
# train: 38.21%
# train: 38.29%
# train: 38.36%
# train: 38.43%
# train: 38.50%
# train: 38.57%
# train: 38.64%
# train: 38.71%
# train: 38.79%
# train: 38.86%
# train: 38.93%
# train: 39.00%
# train: 39.07%
# train: 39.14%
# train: 39.21%
# train: 39.29%
# train: 39.36%
# train: 39.43%
# train: 39.50%
# train: 39.57%
# train: 39.64%
# train: 39.71%
# train: 39.79%
# train: 39.86%
# train: 39.93%
# train: 40.00%
# train: 40.07%
# train: 40.14%
# train: 40.21%
# train: 40.29%
# train: 40.36%
# train: 40.43%
# train: 40.50%
# train: 40.57%
# train: 40.64%
# train: 40.71%
# train: 40.79%
# train: 40.86%
# train: 40.93%
# train: 41.00%
# train: 41.07%
# train: 41.14%
# train: 41.21%
# train: 41.29%
# train: 41.36%
# train: 41.43%
# train: 41.50%
# train: 41.57%
# train: 41.64%
# train: 41.71%
# train: 41.79%
# train: 41.86%
# train: 41.93%
# train: 42.00%
# train: 42.07%
# train: 42.14%
# train: 42.21%
# train: 42.29%
# train: 42.36%
# train: 42.43%
# train: 42.50%
# train: 42.57%
# train: 42.64%
# train: 42.71%
# train: 42.79%
# train: 42.86%
# train: 42.93%
# train: 43.00%
# train: 43.07%
# train: 43.14%
# train: 43.21%
# train: 43.29%
# train: 43.36%
# train: 43.43%
# train: 43.50%
# train: 43.57%
# train: 43.64%
# train: 43.71%
# train: 43.79%
# train: 43.86%
# train: 43.93%
# train: 44.00%
# train: 44.07%
# train: 44.14%
# train: 44.21%
# train: 44.29%
# train: 44.36%
# train: 44.43%
# train: 44.50%
# train: 44.57%
# train: 44.64%
# train: 44.71%
# train: 44.79%
# train: 44.86%
# train: 44.93%
# train: 45.00%
# train: 45.07%
# train: 45.14%
# train: 45.21%
# train: 45.29%
# train: 45.36%
# train: 45.43%
# train: 45.50%
# train: 45.57%
# train: 45.64%
# train: 45.71%
# train: 45.79%
# train: 45.86%
# train: 45.93%
# train: 46.00%
# train: 46.07%
# train: 46.14%
# train: 46.21%
# train: 46.29%
# train: 46.36%
# train: 46.43%
# train: 46.50%
# train: 46.57%
# train: 46.64%
# train: 46.71%
# train: 46.79%
# train: 46.86%
# train: 46.93%
# train: 47.00%
# train: 47.07%
# train: 47.14%
# train: 47.21%
# train: 47.29%
# train: 47.36%
# train: 47.43%
# train: 47.50%
# train: 47.57%
# train: 47.64%
# train: 47.71%
# train: 47.79%
# train: 47.86%
# train: 47.93%
# train: 48.00%
# train: 48.07%
# train: 48.14%
# train: 48.21%
# train: 48.29%
# train: 48.36%
# train: 48.43%
# train: 48.50%
# train: 48.57%
# train: 48.64%
# train: 48.71%
# train: 48.79%
# train: 48.86%
# train: 48.93%
# train: 49.00%
# train: 49.07%
# train: 49.14%
# train: 49.21%
# train: 49.29%
# train: 49.36%
# train: 49.43%
# train: 49.50%
# train: 49.57%
# train: 49.64%
# train: 49.71%
# train: 49.79%
# train: 49.86%
# train: 49.93%
# train: 50.00%
# train: 50.07%
# train: 50.14%
# train: 50.21%
# train: 50.29%
# train: 50.36%
# train: 50.43%
# train: 50.50%
# train: 50.57%
# train: 50.64%
# train: 50.71%
# train: 50.79%
# train: 50.86%
# train: 50.93%
# train: 51.00%
# train: 51.07%
# train: 51.14%
# train: 51.21%
# train: 51.29%
# train: 51.36%
# train: 51.43%
# train: 51.50%
# train: 51.57%
# train: 51.64%
# train: 51.71%
# train: 51.79%
# train: 51.86%
# train: 51.93%
# train: 52.00%
# train: 52.07%
# train: 52.14%
# train: 52.21%
# train: 52.29%
# train: 52.36%
# train: 52.43%
# train: 52.50%
# train: 52.57%
# train: 52.64%
# train: 52.71%
# train: 52.79%
# train: 52.86%
# train: 52.93%
# train: 53.00%
# train: 53.07%
# train: 53.14%
# train: 53.21%
# train: 53.29%
# train: 53.36%
# train: 53.43%
# train: 53.50%
# train: 53.57%
# train: 53.64%
# train: 53.71%
# train: 53.79%
# train: 53.86%
# train: 53.93%
# train: 54.00%
# train: 54.07%
# train: 54.14%
# train: 54.21%
# train: 54.29%
# train: 54.36%
# train: 54.43%
# train: 54.50%
# train: 54.57%
# train: 54.64%
# train: 54.71%
# train: 54.79%
# train: 54.86%
# train: 54.93%
# train: 55.00%
# train: 55.07%
# train: 55.14%
# train: 55.21%
# train: 55.29%
# train: 55.36%
# train: 55.43%
# train: 55.50%
# train: 55.57%
# train: 55.64%
# train: 55.71%
# train: 55.79%
# train: 55.86%
# train: 55.93%
# train: 56.00%
# train: 56.07%
# train: 56.14%
# train: 56.21%
# train: 56.29%
# train: 56.36%
# train: 56.43%
# train: 56.50%
# train: 56.57%
# train: 56.64%
# train: 56.71%
# train: 56.79%
# train: 56.86%
# train: 56.93%
# train: 57.00%
# train: 57.07%
# train: 57.14%
# train: 57.21%
# train: 57.29%
# train: 57.36%
# train: 57.43%
# train: 57.50%
# train: 57.57%
# train: 57.64%
# train: 57.71%
# train: 57.79%
# train: 57.86%
# train: 57.93%
# train: 58.00%
# train: 58.07%
# train: 58.14%
# train: 58.21%
# train: 58.29%
# train: 58.36%
# train: 58.43%
# train: 58.50%
# train: 58.57%
# train: 58.64%
# train: 58.71%
# train: 58.79%
# train: 58.86%
# train: 58.93%
# train: 59.00%
# train: 59.07%
# train: 59.14%
# train: 59.21%
# train: 59.29%
# train: 59.36%
# train: 59.43%
# train: 59.50%
# train: 59.57%
# train: 59.64%
# train: 59.71%
# train: 59.79%
# train: 59.86%
# train: 59.93%
# train: 60.00%
# train: 60.07%
# train: 60.14%
# train: 60.21%
# train: 60.29%
# train: 60.36%
# train: 60.43%
# train: 60.50%
# train: 60.57%
# train: 60.64%
# train: 60.71%
# train: 60.79%
# train: 60.86%
# train: 60.93%
# train: 61.00%
# train: 61.07%
# train: 61.14%
# train: 61.21%
# train: 61.29%
# train: 61.36%
# train: 61.43%
# train: 61.50%
# train: 61.57%
# train: 61.64%
# train: 61.71%
# train: 61.79%
# train: 61.86%
# train: 61.93%
# train: 62.00%
# train: 62.07%
# train: 62.14%
# train: 62.21%
# train: 62.29%
# train: 62.36%
# train: 62.43%
# train: 62.50%
# train: 62.57%
# train: 62.64%
# train: 62.71%
# train: 62.79%
# train: 62.86%
# train: 62.93%
# train: 63.00%
# train: 63.07%
# train: 63.14%
# train: 63.21%
# train: 63.29%
# train: 63.36%
# train: 63.43%
# train: 63.50%
# train: 63.57%
# train: 63.64%
# train: 63.71%
# train: 63.79%
# train: 63.86%
# train: 63.93%
# train: 64.00%
# train: 64.07%
# train: 64.14%
# train: 64.21%
# train: 64.29%
# train: 64.36%
# train: 64.43%
# train: 64.50%
# train: 64.57%
# train: 64.64%
# train: 64.71%
# train: 64.79%
# train: 64.86%
# train: 64.93%
# train: 65.00%
# train: 65.07%
# train: 65.14%
# train: 65.21%
# train: 65.29%
# train: 65.36%
# train: 65.43%
# train: 65.50%
# train: 65.57%
# train: 65.64%
# train: 65.71%
# train: 65.79%
# train: 65.86%
# train: 65.93%
# train: 66.00%
# train: 66.07%
# train: 66.14%
# train: 66.21%
# train: 66.29%
# train: 66.36%
# train: 66.43%
# train: 66.50%
# train: 66.57%
# train: 66.64%
# train: 66.71%
# train: 66.79%
# train: 66.86%
# train: 66.93%
# train: 67.00%
# train: 67.07%
# train: 67.14%
# train: 67.21%
# train: 67.29%
# train: 67.36%
# train: 67.43%
# train: 67.50%
# train: 67.57%
# train: 67.64%
# train: 67.71%
# train: 67.79%
# train: 67.86%
# train: 67.93%
# train: 68.00%
# train: 68.07%
# train: 68.14%
# train: 68.21%
# train: 68.29%
# train: 68.36%
# train: 68.43%
# train: 68.50%
# train: 68.57%
# train: 68.64%
# train: 68.71%
# train: 68.79%
# train: 68.86%
# train: 68.93%
# train: 69.00%
# train: 69.07%
# train: 69.14%
# train: 69.21%
# train: 69.29%
# train: 69.36%
# train: 69.43%
# train: 69.50%
# train: 69.57%
# train: 69.64%
# train: 69.71%
# train: 69.79%
# train: 69.86%
# train: 69.93%
# train: 70.00%
# train: 70.07%
# train: 70.14%
# train: 70.21%
# train: 70.29%
# train: 70.36%
# train: 70.43%
# train: 70.50%
# train: 70.57%
# train: 70.64%
# train: 70.71%
# train: 70.79%
# train: 70.86%
# train: 70.93%
# train: 71.00%
# train: 71.07%
# train: 71.14%
# train: 71.21%
# train: 71.29%
# train: 71.36%
# train: 71.43%
# train: 71.50%
# train: 71.57%
# train: 71.64%
# train: 71.71%
# train: 71.79%
# train: 71.86%
# train: 71.93%
# train: 72.00%
# train: 72.07%
# train: 72.14%
# train: 72.21%
# train: 72.29%
# train: 72.36%
# train: 72.43%
# train: 72.50%
# train: 72.57%
# train: 72.64%
# train: 72.71%
# train: 72.79%
# train: 72.86%
# train: 72.93%
# train: 73.00%
# train: 73.07%
# train: 73.14%
# train: 73.21%
# train: 73.29%
# train: 73.36%
# train: 73.43%
# train: 73.50%
# train: 73.57%
# train: 73.64%
# train: 73.71%
# train: 73.79%
# train: 73.86%
# train: 73.93%
# train: 74.00%
# train: 74.07%
# train: 74.14%
# train: 74.21%
# train: 74.29%
# train: 74.36%
# train: 74.43%
# train: 74.50%
# train: 74.57%
# train: 74.64%
# train: 74.71%
# train: 74.79%
# train: 74.86%
# train: 74.93%
# train: 75.00%
# train: 75.07%
# train: 75.14%
# train: 75.21%
# train: 75.29%
# train: 75.36%
# train: 75.43%
# train: 75.50%
# train: 75.57%
# train: 75.64%
# train: 75.71%
# train: 75.79%
# train: 75.86%
# train: 75.93%
# train: 76.00%
# train: 76.07%
# train: 76.14%
# train: 76.21%
# train: 76.29%
# train: 76.36%
# train: 76.43%
# train: 76.50%
# train: 76.57%
# train: 76.64%
# train: 76.71%
# train: 76.79%
# train: 76.86%
# train: 76.93%
# train: 77.00%
# train: 77.07%
# train: 77.14%
# train: 77.21%
# train: 77.29%
# train: 77.36%
# train: 77.43%
# train: 77.50%
# train: 77.57%
# train: 77.64%
# train: 77.71%
# train: 77.79%
# train: 77.86%
# train: 77.93%
# train: 78.00%
# train: 78.07%
# train: 78.14%
# train: 78.21%
# train: 78.29%
# train: 78.36%
# train: 78.43%
# train: 78.50%
# train: 78.57%
# train: 78.64%
# train: 78.71%
# train: 78.79%
# train: 78.86%
# train: 78.93%
# train: 79.00%
# train: 79.07%
# train: 79.14%
# train: 79.21%
# train: 79.29%
# train: 79.36%
# train: 79.43%
# train: 79.50%
# train: 79.57%
# train: 79.64%
# train: 79.71%
# train: 79.79%
# train: 79.86%
# train: 79.93%
# train: 80.00%
# train: 80.07%
# train: 80.14%
# train: 80.21%
# train: 80.29%
# train: 80.36%
# train: 80.43%
# train: 80.50%
# train: 80.57%
# train: 80.64%
# train: 80.71%
# train: 80.79%
# train: 80.86%
# train: 80.93%
# train: 81.00%
# train: 81.07%
# train: 81.14%
# train: 81.21%
# train: 81.29%
# train: 81.36%
# train: 81.43%
# train: 81.50%
# train: 81.57%
# train: 81.64%
# train: 81.71%
# train: 81.79%
# train: 81.86%
# train: 81.93%
# train: 82.00%
# train: 82.07%
# train: 82.14%
# train: 82.21%
# train: 82.29%
# train: 82.36%
# train: 82.43%
# train: 82.50%
# train: 82.57%
# train: 82.64%
# train: 82.71%
# train: 82.79%
# train: 82.86%
# train: 82.93%
# train: 83.00%
# train: 83.07%
# train: 83.14%
# train: 83.21%
# train: 83.29%
# train: 83.36%
# train: 83.43%
# train: 83.50%
# train: 83.57%
# train: 83.64%
# train: 83.71%
# train: 83.79%
# train: 83.86%
# train: 83.93%
# train: 84.00%
# train: 84.07%
# train: 84.14%
# train: 84.21%
# train: 84.29%
# train: 84.36%
# train: 84.43%
# train: 84.50%
# train: 84.57%
# train: 84.64%
# train: 84.71%
# train: 84.79%
# train: 84.86%
# train: 84.93%
# train: 85.00%
# train: 85.07%
# train: 85.14%
# train: 85.21%
# train: 85.29%
# train: 85.36%
# train: 85.43%
# train: 85.50%
# train: 85.57%
# train: 85.64%
# train: 85.71%
# train: 85.79%
# train: 85.86%
# train: 85.93%
# train: 86.00%
# train: 86.07%
# train: 86.14%
# train: 86.21%
# train: 86.29%
# train: 86.36%
# train: 86.43%
# train: 86.50%
# train: 86.57%
# train: 86.64%
# train: 86.71%
# train: 86.79%
# train: 86.86%
# train: 86.93%
# train: 87.00%
# train: 87.07%
# train: 87.14%
# train: 87.21%
# train: 87.29%
# train: 87.36%
# train: 87.43%
# train: 87.50%
# train: 87.57%
# train: 87.64%
# train: 87.71%
# train: 87.79%
# train: 87.86%
# train: 87.93%
# train: 88.00%
# train: 88.07%
# train: 88.14%
# train: 88.21%
# train: 88.29%
# train: 88.36%
# train: 88.43%
# train: 88.50%
# train: 88.57%
# train: 88.64%
# train: 88.71%
# train: 88.79%
# train: 88.86%
# train: 88.93%
# train: 89.00%
# train: 89.07%
# train: 89.14%
# train: 89.21%
# train: 89.29%
# train: 89.36%
# train: 89.43%
# train: 89.50%
# train: 89.57%
# train: 89.64%
# train: 89.71%
# train: 89.79%
# train: 89.86%
# train: 89.93%
# train: 90.00%
# train: 90.07%
# train: 90.14%
# train: 90.21%
# train: 90.29%
# train: 90.36%
# train: 90.43%
# train: 90.50%
# train: 90.57%
# train: 90.64%
# train: 90.71%
# train: 90.79%
# train: 90.86%
# train: 90.93%
# train: 91.00%
# train: 91.07%
# train: 91.14%
# train: 91.21%
# train: 91.29%
# train: 91.36%
# train: 91.43%
# train: 91.50%
# train: 91.57%
# train: 91.64%
# train: 91.71%
# train: 91.79%
# train: 91.86%
# train: 91.93%
# train: 92.00%
# train: 92.07%
# train: 92.14%
# train: 92.21%
# train: 92.29%
# train: 92.36%
# train: 92.43%
# train: 92.50%
# train: 92.57%
# train: 92.64%
# train: 92.71%
# train: 92.79%
# train: 92.86%
# train: 92.93%
# train: 93.00%
# train: 93.07%
# train: 93.14%
# train: 93.21%
# train: 93.29%
# train: 93.36%
# train: 93.43%
# train: 93.50%
# train: 93.57%
# train: 93.64%
# train: 93.71%
# train: 93.79%
# train: 93.86%
# train: 93.93%
# train: 94.00%
# train: 94.07%
# train: 94.14%
# train: 94.21%
# train: 94.29%
# train: 94.36%
# train: 94.43%
# train: 94.50%
# train: 94.57%
# train: 94.64%
# train: 94.71%
# train: 94.79%
# train: 94.86%
# train: 94.93%
# train: 95.00%
# train: 95.07%
# train: 95.14%
# train: 95.21%
# train: 95.29%
# train: 95.36%
# train: 95.43%
# train: 95.50%
# train: 95.57%
# train: 95.64%
# train: 95.71%
# train: 95.79%
# train: 95.86%
# train: 95.93%
# train: 96.00%
# train: 96.07%
# train: 96.14%
# train: 96.21%
# train: 96.29%
# train: 96.36%
# train: 96.43%
# train: 96.50%
# train: 96.57%
# train: 96.64%
# train: 96.71%
# train: 96.79%
# train: 96.86%
# train: 96.93%
# train: 97.00%
# train: 97.07%
# train: 97.14%
# train: 97.21%
# train: 97.29%
# train: 97.36%
# train: 97.43%
# train: 97.50%
# train: 97.57%
# train: 97.64%
# train: 97.71%
# train: 97.79%
# train: 97.86%
# train: 97.93%
# train: 98.00%
# train: 98.07%
# train: 98.14%
# train: 98.21%
# train: 98.29%
# train: 98.36%
# train: 98.43%
# train: 98.50%
# train: 98.57%
# train: 98.64%
# train: 98.71%
# train: 98.79%
# train: 98.86%
# train: 98.93%
# train: 99.00%
# train: 99.07%
# train: 99.14%
# train: 99.21%
# train: 99.29%
# train: 99.36%
# train: 99.43%
# train: 99.50%
# train: 99.57%
# train: 99.64%
# train: 99.71%
# train: 99.79%
# train: 99.86%
# train: 99.93%
# train: 100.00%
# valid
# valid: 0.00%
# valid: 0.25%
# valid: 0.49%
# valid: 0.74%
# valid: 0.99%
# valid: 1.23%
# valid: 1.48%
# valid: 1.73%
# valid: 1.98%
# valid: 2.22%
# valid: 2.47%
# valid: 2.72%
# valid: 2.96%
# valid: 3.21%
# valid: 3.46%
# valid: 3.70%
# valid: 3.95%
# valid: 4.20%
# valid: 4.44%
# valid: 4.69%
# valid: 4.94%
# valid: 5.19%
# valid: 5.43%
# valid: 5.68%
# valid: 5.93%
# valid: 6.17%
# valid: 6.42%
# valid: 6.67%
# valid: 6.91%
# valid: 7.16%
# valid: 7.41%
# valid: 7.65%
# valid: 7.90%
# valid: 8.15%
# valid: 8.40%
# valid: 8.64%
# valid: 8.89%
# valid: 9.14%
# valid: 9.38%
# valid: 9.63%
# valid: 9.88%
# valid: 10.12%
# valid: 10.37%
# valid: 10.62%
# valid: 10.86%
# valid: 11.11%
# valid: 11.36%
# valid: 11.60%
# valid: 11.85%
# valid: 12.10%
# valid: 12.35%
# valid: 12.59%
# valid: 12.84%
# valid: 13.09%
# valid: 13.33%
# valid: 13.58%
# valid: 13.83%
# valid: 14.07%
# valid: 14.32%
# valid: 14.57%
# valid: 14.81%
# valid: 15.06%
# valid: 15.31%
# valid: 15.56%
# valid: 15.80%
# valid: 16.05%
# valid: 16.30%
# valid: 16.54%
# valid: 16.79%
# valid: 17.04%
# valid: 17.28%
# valid: 17.53%
# valid: 17.78%
# valid: 18.02%
# valid: 18.27%
# valid: 18.52%
# valid: 18.77%
# valid: 19.01%
# valid: 19.26%
# valid: 19.51%
# valid: 19.75%
# valid: 20.00%
# valid: 20.25%
# valid: 20.49%
# valid: 20.74%
# valid: 20.99%
# valid: 21.23%
# valid: 21.48%
# valid: 21.73%
# valid: 21.98%
# valid: 22.22%
# valid: 22.47%
# valid: 22.72%
# valid: 22.96%
# valid: 23.21%
# valid: 23.46%
# valid: 23.70%
# valid: 23.95%
# valid: 24.20%
# valid: 24.44%
# valid: 24.69%
# valid: 24.94%
# valid: 25.19%
# valid: 25.43%
# valid: 25.68%
# valid: 25.93%
# valid: 26.17%
# valid: 26.42%
# valid: 26.67%
# valid: 26.91%
# valid: 27.16%
# valid: 27.41%
# valid: 27.65%
# valid: 27.90%
# valid: 28.15%
# valid: 28.40%
# valid: 28.64%
# valid: 28.89%
# valid: 29.14%
# valid: 29.38%
# valid: 29.63%
# valid: 29.88%
# valid: 30.12%
# valid: 30.37%
# valid: 30.62%
# valid: 30.86%
# valid: 31.11%
# valid: 31.36%
# valid: 31.60%
# valid: 31.85%
# valid: 32.10%
# valid: 32.35%
# valid: 32.59%
# valid: 32.84%
# valid: 33.09%
# valid: 33.33%
# valid: 33.58%
# valid: 33.83%
# valid: 34.07%
# valid: 34.32%
# valid: 34.57%
# valid: 34.81%
# valid: 35.06%
# valid: 35.31%
# valid: 35.56%
# valid: 35.80%
# valid: 36.05%
# valid: 36.30%
# valid: 36.54%
# valid: 36.79%
# valid: 37.04%
# valid: 37.28%
# valid: 37.53%
# valid: 37.78%
# valid: 38.02%
# valid: 38.27%
# valid: 38.52%
# valid: 38.77%
# valid: 39.01%
# valid: 39.26%
# valid: 39.51%
# valid: 39.75%
# valid: 40.00%
# valid: 40.25%
# valid: 40.49%
# valid: 40.74%
# valid: 40.99%
# valid: 41.23%
# valid: 41.48%
# valid: 41.73%
# valid: 41.98%
# valid: 42.22%
# valid: 42.47%
# valid: 42.72%
# valid: 42.96%
# valid: 43.21%
# valid: 43.46%
# valid: 43.70%
# valid: 43.95%
# valid: 44.20%
# valid: 44.44%
# valid: 44.69%
# valid: 44.94%
# valid: 45.19%
# valid: 45.43%
# valid: 45.68%
# valid: 45.93%
# valid: 46.17%
# valid: 46.42%
# valid: 46.67%
# valid: 46.91%
# valid: 47.16%
# valid: 47.41%
# valid: 47.65%
# valid: 47.90%
# valid: 48.15%
# valid: 48.40%
# valid: 48.64%
# valid: 48.89%
# valid: 49.14%
# valid: 49.38%
# valid: 49.63%
# valid: 49.88%
# valid: 50.12%
# valid: 50.37%
# valid: 50.62%
# valid: 50.86%
# valid: 51.11%
# valid: 51.36%
# valid: 51.60%
# valid: 51.85%
# valid: 52.10%
# valid: 52.35%
# valid: 52.59%
# valid: 52.84%
# valid: 53.09%
# valid: 53.33%
# valid: 53.58%
# valid: 53.83%
# valid: 54.07%
# valid: 54.32%
# valid: 54.57%
# valid: 54.81%
# valid: 55.06%
# valid: 55.31%
# valid: 55.56%
# valid: 55.80%
# valid: 56.05%
# valid: 56.30%
# valid: 56.54%
# valid: 56.79%
# valid: 57.04%
# valid: 57.28%
# valid: 57.53%
# valid: 57.78%
# valid: 58.02%
# valid: 58.27%
# valid: 58.52%
# valid: 58.77%
# valid: 59.01%
# valid: 59.26%
# valid: 59.51%
# valid: 59.75%
# valid: 60.00%
# valid: 60.25%
# valid: 60.49%
# valid: 60.74%
# valid: 60.99%
# valid: 61.23%
# valid: 61.48%
# valid: 61.73%
# valid: 61.98%
# valid: 62.22%
# valid: 62.47%
# valid: 62.72%
# valid: 62.96%
# valid: 63.21%
# valid: 63.46%
# valid: 63.70%
# valid: 63.95%
# valid: 64.20%
# valid: 64.44%
# valid: 64.69%
# valid: 64.94%
# valid: 65.19%
# valid: 65.43%
# valid: 65.68%
# valid: 65.93%
# valid: 66.17%
# valid: 66.42%
# valid: 66.67%
# valid: 66.91%
# valid: 67.16%
# valid: 67.41%
# valid: 67.65%
# valid: 67.90%
# valid: 68.15%
# valid: 68.40%
# valid: 68.64%
# valid: 68.89%
# valid: 69.14%
# valid: 69.38%
# valid: 69.63%
# valid: 69.88%
# valid: 70.12%
# valid: 70.37%
# valid: 70.62%
# valid: 70.86%
# valid: 71.11%
# valid: 71.36%
# valid: 71.60%
# valid: 71.85%
# valid: 72.10%
# valid: 72.35%
# valid: 72.59%
# valid: 72.84%
# valid: 73.09%
# valid: 73.33%
# valid: 73.58%
# valid: 73.83%
# valid: 74.07%
# valid: 74.32%
# valid: 74.57%
# valid: 74.81%
# valid: 75.06%
# valid: 75.31%
# valid: 75.56%
# valid: 75.80%
# valid: 76.05%
# valid: 76.30%
# valid: 76.54%
# valid: 76.79%
# valid: 77.04%
# valid: 77.28%
# valid: 77.53%
# valid: 77.78%
# valid: 78.02%
# valid: 78.27%
# valid: 78.52%
# valid: 78.77%
# valid: 79.01%
# valid: 79.26%
# valid: 79.51%
# valid: 79.75%
# valid: 80.00%
# valid: 80.25%
# valid: 80.49%
# valid: 80.74%
# valid: 80.99%
# valid: 81.23%
# valid: 81.48%
# valid: 81.73%
# valid: 81.98%
# valid: 82.22%
# valid: 82.47%
# valid: 82.72%
# valid: 82.96%
# valid: 83.21%
# valid: 83.46%
# valid: 83.70%
# valid: 83.95%
# valid: 84.20%
# valid: 84.44%
# valid: 84.69%
# valid: 84.94%
# valid: 85.19%
# valid: 85.43%
# valid: 85.68%
# valid: 85.93%
# valid: 86.17%
# valid: 86.42%
# valid: 86.67%
# valid: 86.91%
# valid: 87.16%
# valid: 87.41%
# valid: 87.65%
# valid: 87.90%
# valid: 88.15%
# valid: 88.40%
# valid: 88.64%
# valid: 88.89%
# valid: 89.14%
# valid: 89.38%
# valid: 89.63%
# valid: 89.88%
# valid: 90.12%
# valid: 90.37%
# valid: 90.62%
# valid: 90.86%
# valid: 91.11%
# valid: 91.36%
# valid: 91.60%
# valid: 91.85%
# valid: 92.10%
# valid: 92.35%
# valid: 92.59%
# valid: 92.84%
# valid: 93.09%
# valid: 93.33%
# valid: 93.58%
# valid: 93.83%
# valid: 94.07%
# valid: 94.32%
# valid: 94.57%
# valid: 94.81%
# valid: 95.06%
# valid: 95.31%
# valid: 95.56%
# valid: 95.80%
# valid: 96.05%
# valid: 96.30%
# valid: 96.54%
# valid: 96.79%
# valid: 97.04%
# valid: 97.28%
# valid: 97.53%
# valid: 97.78%
# valid: 98.02%
# valid: 98.27%
# valid: 98.52%
# valid: 98.77%
# valid: 99.01%
# valid: 99.26%
# valid: 99.51%
# valid: 99.75%
# valid: 100.00%
# test
# test: 0.00%
# test: 0.13%
# test: 0.25%
# test: 0.38%
# test: 0.51%
# test: 0.63%
# test: 0.76%
# test: 0.88%
# test: 1.01%
# test: 1.14%
# test: 1.26%
# test: 1.39%
# test: 1.52%
# test: 1.64%
# test: 1.77%
# test: 1.89%
# test: 2.02%
# test: 2.15%
# test: 2.27%
# test: 2.40%
# test: 2.53%
# test: 2.65%
# test: 2.78%
# test: 2.90%
# test: 3.03%
# test: 3.16%
# test: 3.28%
# test: 3.41%
# test: 3.54%
# test: 3.66%
# test: 3.79%
# test: 3.91%
# test: 4.04%
# test: 4.17%
# test: 4.29%
# test: 4.42%
# test: 4.55%
# test: 4.67%
# test: 4.80%
# test: 4.92%
# test: 5.05%
# test: 5.18%
# test: 5.30%
# test: 5.43%
# test: 5.56%
# test: 5.68%
# test: 5.81%
# test: 5.93%
# test: 6.06%
# test: 6.19%
# test: 6.31%
# test: 6.44%
# test: 6.57%
# test: 6.69%
# test: 6.82%
# test: 6.94%
# test: 7.07%
# test: 7.20%
# test: 7.32%
# test: 7.45%
# test: 7.58%
# test: 7.70%
# test: 7.83%
# test: 7.95%
# test: 8.08%
# test: 8.21%
# test: 8.33%
# test: 8.46%
# test: 8.59%
# test: 8.71%
# test: 8.84%
# test: 8.96%
# test: 9.09%
# test: 9.22%
# test: 9.34%
# test: 9.47%
# test: 9.60%
# test: 9.72%
# test: 9.85%
# test: 9.97%
# test: 10.10%
# test: 10.23%
# test: 10.35%
# test: 10.48%
# test: 10.61%
# test: 10.73%
# test: 10.86%
# test: 10.98%
# test: 11.11%
# test: 11.24%
# test: 11.36%
# test: 11.49%
# test: 11.62%
# test: 11.74%
# test: 11.87%
# test: 11.99%
# test: 12.12%
# test: 12.25%
# test: 12.37%
# test: 12.50%
# test: 12.63%
# test: 12.75%
# test: 12.88%
# test: 13.01%
# test: 13.13%
# test: 13.26%
# test: 13.38%
# test: 13.51%
# test: 13.64%
# test: 13.76%
# test: 13.89%
# test: 14.02%
# test: 14.14%
# test: 14.27%
# test: 14.39%
# test: 14.52%
# test: 14.65%
# test: 14.77%
# test: 14.90%
# test: 15.03%
# test: 15.15%
# test: 15.28%
# test: 15.40%
# test: 15.53%
# test: 15.66%
# test: 15.78%
# test: 15.91%
# test: 16.04%
# test: 16.16%
# test: 16.29%
# test: 16.41%
# test: 16.54%
# test: 16.67%
# test: 16.79%
# test: 16.92%
# test: 17.05%
# test: 17.17%
# test: 17.30%
# test: 17.42%
# test: 17.55%
# test: 17.68%
# test: 17.80%
# test: 17.93%
# test: 18.06%
# test: 18.18%
# test: 18.31%
# test: 18.43%
# test: 18.56%
# test: 18.69%
# test: 18.81%
# test: 18.94%
# test: 19.07%
# test: 19.19%
# test: 19.32%
# test: 19.44%
# test: 19.57%
# test: 19.70%
# test: 19.82%
# test: 19.95%
# test: 20.08%
# test: 20.20%
# test: 20.33%
# test: 20.45%
# test: 20.58%
# test: 20.71%
# test: 20.83%
# test: 20.96%
# test: 21.09%
# test: 21.21%
# test: 21.34%
# test: 21.46%
# test: 21.59%
# test: 21.72%
# test: 21.84%
# test: 21.97%
# test: 22.10%
# test: 22.22%
# test: 22.35%
# test: 22.47%
# test: 22.60%
# test: 22.73%
# test: 22.85%
# test: 22.98%
# test: 23.11%
# test: 23.23%
# test: 23.36%
# test: 23.48%
# test: 23.61%
# test: 23.74%
# test: 23.86%
# test: 23.99%
# test: 24.12%
# test: 24.24%
# test: 24.37%
# test: 24.49%
# test: 24.62%
# test: 24.75%
# test: 24.87%
# test: 25.00%
# test: 25.13%
# test: 25.25%
# test: 25.38%
# test: 25.51%
# test: 25.63%
# test: 25.76%
# test: 25.88%
# test: 26.01%
# test: 26.14%
# test: 26.26%
# test: 26.39%
# test: 26.52%
# test: 26.64%
# test: 26.77%
# test: 26.89%
# test: 27.02%
# test: 27.15%
# test: 27.27%
# test: 27.40%
# test: 27.53%
# test: 27.65%
# test: 27.78%
# test: 27.90%
# test: 28.03%
# test: 28.16%
# test: 28.28%
# test: 28.41%
# test: 28.54%
# test: 28.66%
# test: 28.79%
# test: 28.91%
# test: 29.04%
# test: 29.17%
# test: 29.29%
# test: 29.42%
# test: 29.55%
# test: 29.67%
# test: 29.80%
# test: 29.92%
# test: 30.05%
# test: 30.18%
# test: 30.30%
# test: 30.43%
# test: 30.56%
# test: 30.68%
# test: 30.81%
# test: 30.93%
# test: 31.06%
# test: 31.19%
# test: 31.31%
# test: 31.44%
# test: 31.57%
# test: 31.69%
# test: 31.82%
# test: 31.94%
# test: 32.07%
# test: 32.20%
# test: 32.32%
# test: 32.45%
# test: 32.58%
# test: 32.70%
# test: 32.83%
# test: 32.95%
# test: 33.08%
# test: 33.21%
# test: 33.33%
# test: 33.46%
# test: 33.59%
# test: 33.71%
# test: 33.84%
# test: 33.96%
# test: 34.09%
# test: 34.22%
# test: 34.34%
# test: 34.47%
# test: 34.60%
# test: 34.72%
# test: 34.85%
# test: 34.97%
# test: 35.10%
# test: 35.23%
# test: 35.35%
# test: 35.48%
# test: 35.61%
# test: 35.73%
# test: 35.86%
# test: 35.98%
# test: 36.11%
# test: 36.24%
# test: 36.36%
# test: 36.49%
# test: 36.62%
# test: 36.74%
# test: 36.87%
# test: 36.99%
# test: 37.12%
# test: 37.25%
# test: 37.37%
# test: 37.50%
# test: 37.63%
# test: 37.75%
# test: 37.88%
# test: 38.01%
# test: 38.13%
# test: 38.26%
# test: 38.38%
# test: 38.51%
# test: 38.64%
# test: 38.76%
# test: 38.89%
# test: 39.02%
# test: 39.14%
# test: 39.27%
# test: 39.39%
# test: 39.52%
# test: 39.65%
# test: 39.77%
# test: 39.90%
# test: 40.03%
# test: 40.15%
# test: 40.28%
# test: 40.40%
# test: 40.53%
# test: 40.66%
# test: 40.78%
# test: 40.91%
# test: 41.04%
# test: 41.16%
# test: 41.29%
# test: 41.41%
# test: 41.54%
# test: 41.67%
# test: 41.79%
# test: 41.92%
# test: 42.05%
# test: 42.17%
# test: 42.30%
# test: 42.42%
# test: 42.55%
# test: 42.68%
# test: 42.80%
# test: 42.93%
# test: 43.06%
# test: 43.18%
# test: 43.31%
# test: 43.43%
# test: 43.56%
# test: 43.69%
# test: 43.81%
# test: 43.94%
# test: 44.07%
# test: 44.19%
# test: 44.32%
# test: 44.44%
# test: 44.57%
# test: 44.70%
# test: 44.82%
# test: 44.95%
# test: 45.08%
# test: 45.20%
# test: 45.33%
# test: 45.45%
# test: 45.58%
# test: 45.71%
# test: 45.83%
# test: 45.96%
# test: 46.09%
# test: 46.21%
# test: 46.34%
# test: 46.46%
# test: 46.59%
# test: 46.72%
# test: 46.84%
# test: 46.97%
# test: 47.10%
# test: 47.22%
# test: 47.35%
# test: 47.47%
# test: 47.60%
# test: 47.73%
# test: 47.85%
# test: 47.98%
# test: 48.11%
# test: 48.23%
# test: 48.36%
# test: 48.48%
# test: 48.61%
# test: 48.74%
# test: 48.86%
# test: 48.99%
# test: 49.12%
# test: 49.24%
# test: 49.37%
# test: 49.49%
# test: 49.62%
# test: 49.75%
# test: 49.87%
# test: 50.00%
# test: 50.13%
# test: 50.25%
# test: 50.38%
# test: 50.51%
# test: 50.63%
# test: 50.76%
# test: 50.88%
# test: 51.01%
# test: 51.14%
# test: 51.26%
# test: 51.39%
# test: 51.52%
# test: 51.64%
# test: 51.77%
# test: 51.89%
# test: 52.02%
# test: 52.15%
# test: 52.27%
# test: 52.40%
# test: 52.53%
# test: 52.65%
# test: 52.78%
# test: 52.90%
# test: 53.03%
# test: 53.16%
# test: 53.28%
# test: 53.41%
# test: 53.54%
# test: 53.66%
# test: 53.79%
# test: 53.91%
# test: 54.04%
# test: 54.17%
# test: 54.29%
# test: 54.42%
# test: 54.55%
# test: 54.67%
# test: 54.80%
# test: 54.92%
# test: 55.05%
# test: 55.18%
# test: 55.30%
# test: 55.43%
# test: 55.56%
# test: 55.68%
# test: 55.81%
# test: 55.93%
# test: 56.06%
# test: 56.19%
# test: 56.31%
# test: 56.44%
# test: 56.57%
# test: 56.69%
# test: 56.82%
# test: 56.94%
# test: 57.07%
# test: 57.20%
# test: 57.32%
# test: 57.45%
# test: 57.58%
# test: 57.70%
# test: 57.83%
# test: 57.95%
# test: 58.08%
# test: 58.21%
# test: 58.33%
# test: 58.46%
# test: 58.59%
# test: 58.71%
# test: 58.84%
# test: 58.96%
# test: 59.09%
# test: 59.22%
# test: 59.34%
# test: 59.47%
# test: 59.60%
# test: 59.72%
# test: 59.85%
# test: 59.97%
# test: 60.10%
# test: 60.23%
# test: 60.35%
# test: 60.48%
# test: 60.61%
# test: 60.73%
# test: 60.86%
# test: 60.98%
# test: 61.11%
# test: 61.24%
# test: 61.36%
# test: 61.49%
# test: 61.62%
# test: 61.74%
# test: 61.87%
# test: 61.99%
# test: 62.12%
# test: 62.25%
# test: 62.37%
# test: 62.50%
# test: 62.63%
# test: 62.75%
# test: 62.88%
# test: 63.01%
# test: 63.13%
# test: 63.26%
# test: 63.38%
# test: 63.51%
# test: 63.64%
# test: 63.76%
# test: 63.89%
# test: 64.02%
# test: 64.14%
# test: 64.27%
# test: 64.39%
# test: 64.52%
# test: 64.65%
# test: 64.77%
# test: 64.90%
# test: 65.03%
# test: 65.15%
# test: 65.28%
# test: 65.40%
# test: 65.53%
# test: 65.66%
# test: 65.78%
# test: 65.91%
# test: 66.04%
# test: 66.16%
# test: 66.29%
# test: 66.41%
# test: 66.54%
# test: 66.67%
# test: 66.79%
# test: 66.92%
# test: 67.05%
# test: 67.17%
# test: 67.30%
# test: 67.42%
# test: 67.55%
# test: 67.68%
# test: 67.80%
# test: 67.93%
# test: 68.06%
# test: 68.18%
# test: 68.31%
# test: 68.43%
# test: 68.56%
# test: 68.69%
# test: 68.81%
# test: 68.94%
# test: 69.07%
# test: 69.19%
# test: 69.32%
# test: 69.44%
# test: 69.57%
# test: 69.70%
# test: 69.82%
# test: 69.95%
# test: 70.08%
# test: 70.20%
# test: 70.33%
# test: 70.45%
# test: 70.58%
# test: 70.71%
# test: 70.83%
# test: 70.96%
# test: 71.09%
# test: 71.21%
# test: 71.34%
# test: 71.46%
# test: 71.59%
# test: 71.72%
# test: 71.84%
# test: 71.97%
# test: 72.10%
# test: 72.22%
# test: 72.35%
# test: 72.47%
# test: 72.60%
# test: 72.73%
# test: 72.85%
# test: 72.98%
# test: 73.11%
# test: 73.23%
# test: 73.36%
# test: 73.48%
# test: 73.61%
# test: 73.74%
# test: 73.86%
# test: 73.99%
# test: 74.12%
# test: 74.24%
# test: 74.37%
# test: 74.49%
# test: 74.62%
# test: 74.75%
# test: 74.87%
# test: 75.00%
# test: 75.13%
# test: 75.25%
# test: 75.38%
# test: 75.51%
# test: 75.63%
# test: 75.76%
# test: 75.88%
# test: 76.01%
# test: 76.14%
# test: 76.26%
# test: 76.39%
# test: 76.52%
# test: 76.64%
# test: 76.77%
# test: 76.89%
# test: 77.02%
# test: 77.15%
# test: 77.27%
# test: 77.40%
# test: 77.53%
# test: 77.65%
# test: 77.78%
# test: 77.90%
# test: 78.03%
# test: 78.16%
# test: 78.28%
# test: 78.41%
# test: 78.54%
# test: 78.66%
# test: 78.79%
# test: 78.91%
# test: 79.04%
# test: 79.17%
# test: 79.29%
# test: 79.42%
# test: 79.55%
# test: 79.67%
# test: 79.80%
# test: 79.92%
# test: 80.05%
# test: 80.18%
# test: 80.30%
# test: 80.43%
# test: 80.56%
# test: 80.68%
# test: 80.81%
# test: 80.93%
# test: 81.06%
# test: 81.19%
# test: 81.31%
# test: 81.44%
# test: 81.57%
# test: 81.69%
# test: 81.82%
# test: 81.94%
# test: 82.07%
# test: 82.20%
# test: 82.32%
# test: 82.45%
# test: 82.58%
# test: 82.70%
# test: 82.83%
# test: 82.95%
# test: 83.08%
# test: 83.21%
# test: 83.33%
# test: 83.46%
# test: 83.59%
# test: 83.71%
# test: 83.84%
# test: 83.96%
# test: 84.09%
# test: 84.22%
# test: 84.34%
# test: 84.47%
# test: 84.60%
# test: 84.72%
# test: 84.85%
# test: 84.97%
# test: 85.10%
# test: 85.23%
# test: 85.35%
# test: 85.48%
# test: 85.61%
# test: 85.73%
# test: 85.86%
# test: 85.98%
# test: 86.11%
# test: 86.24%
# test: 86.36%
# test: 86.49%
# test: 86.62%
# test: 86.74%
# test: 86.87%
# test: 86.99%
# test: 87.12%
# test: 87.25%
# test: 87.37%
# test: 87.50%
# test: 87.63%
# test: 87.75%
# test: 87.88%
# test: 88.01%
# test: 88.13%
# test: 88.26%
# test: 88.38%
# test: 88.51%
# test: 88.64%
# test: 88.76%
# test: 88.89%
# test: 89.02%
# test: 89.14%
# test: 89.27%
# test: 89.39%
# test: 89.52%
# test: 89.65%
# test: 89.77%
# test: 89.90%
# test: 90.03%
# test: 90.15%
# test: 90.28%
# test: 90.40%
# test: 90.53%
# test: 90.66%
# test: 90.78%
# test: 90.91%
# test: 91.04%
# test: 91.16%
# test: 91.29%
# test: 91.41%
# test: 91.54%
# test: 91.67%
# test: 91.79%
# test: 91.92%
# test: 92.05%
# test: 92.17%
# test: 92.30%
# test: 92.42%
# test: 92.55%
# test: 92.68%
# test: 92.80%
# test: 92.93%
# test: 93.06%
# test: 93.18%
# test: 93.31%
# test: 93.43%
# test: 93.56%
# test: 93.69%
# test: 93.81%
# test: 93.94%
# test: 94.07%
# test: 94.19%
# test: 94.32%
# test: 94.44%
# test: 94.57%
# test: 94.70%
# test: 94.82%
# test: 94.95%
# test: 95.08%
# test: 95.20%
# test: 95.33%
# test: 95.45%
# test: 95.58%
# test: 95.71%
# test: 95.83%
# test: 95.96%
# test: 96.09%
# test: 96.21%
# test: 96.34%
# test: 96.46%
# test: 96.59%
# test: 96.72%
# test: 96.84%
# test: 96.97%
# test: 97.10%
# test: 97.22%
# test: 97.35%
# test: 97.47%
# test: 97.60%
# test: 97.73%
# test: 97.85%
# test: 97.98%
# test: 98.11%
# test: 98.23%
# test: 98.36%
# test: 98.48%
# test: 98.61%
# test: 98.74%
# test: 98.86%
# test: 98.99%
# test: 99.12%
# test: 99.24%
# test: 99.37%
# test: 99.49%
# test: 99.62%
# test: 99.75%
# test: 99.87%
# test: 100.00%

# %% [markdown]
# ### Train logistic regression classifier using features

# %%
# Train logistic regression model to classify wake vs MS using features from embedder

from sklearn.metrics import balanced_accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline


# Initialize the logistic regression model
log_reg = LogisticRegression(
    penalty='l2', C=1.0, class_weight='balanced', solver='lbfgs',
    multi_class='auto', random_state=random_state, max_iter=1000)
 
clf_pipe = make_pipeline(StandardScaler(), log_reg)
 
# Make sure that all data is [-1,1]
data['train'][1][data['train'][1] == 0] = -1
data['valid'][1][data['valid'][1] == 0] = -1
data['test'][1][data['test'][1] == 0] = -1 
  
# Fit and score the logistic regression
clf_pipe.fit(*data['train'])
train_y_pred = clf_pipe.predict(data['train'][0])
valid_y_pred = clf_pipe.predict(data['valid'][0])
test_y_pred = clf_pipe.predict(data['test'][0])
 
train_bal_acc = balanced_accuracy_score(data['train'][1], train_y_pred)
valid_bal_acc = balanced_accuracy_score(data['valid'][1], valid_y_pred)
 
print('Sleep staging performance with logistic regression:')
print(f'Train bal acc: {train_bal_acc:0.4f}')
print(f'Valid bal acc: {valid_bal_acc:0.4f}')
 
print('Results on validation set:')
print(confusion_matrix(data['valid'][1], valid_y_pred))
print(classification_report(data['valid'][1], valid_y_pred))
# Out:
# Sleep staging performance with logistic regression:
# Train bal acc: 0.8871
# Valid bal acc: 0.9113
# Results on validation set:
# [[86122  8706]
#  [  778  8314]]
#               precision    recall  f1-score   support
#
#         -1.0       0.99      0.91      0.95     94828
#          1.0       0.49      0.91      0.64      9092
#
#     accuracy                           0.91    103920
#    macro avg       0.74      0.91      0.79    103920
# weighted avg       0.95      0.91      0.92    103920

# %% [markdown]
# ### Find optimal threshold

# %%
# Find optimal thresholding using averaged validation probabilities

# Collect averaged probability data per subject for all channel combinations
val_data = {d.description['subject'].split("@")[0]: {"probs": [], "y": []} 
                for d in windows_dataset.datasets
                     if d.description['subject'].split("@")[0] in split_ids['valid']}
 
for d in windows_dataset.datasets:
    id = d.description['subject'].split("@")[0]
 
    if id not in split_ids['valid']:
        continue
 
    print(d.description['subject'])
    window_data = d.windows.get_data()
    features = emb(torch.Tensor(window_data)).detach().numpy()
    probs = clf_pipe.predict_proba(features)
    val_data[id]["probs"].append(probs)
    val_data[id]["y"] = d.y

# Average probabilites
for k, v in val_data.items():
    all_probs = np.array(v["probs"]).mean(axis=0)[:,1]
    val_data[k]["avg_probs"] = all_probs

 
valid_probs = np.concatenate([v["avg_probs"] for _, v in val_data.items()])
valid_y = np.concatenate([v["y"] for _, v in val_data.items()]) > 0
# Out:
# 9098@O1-M2_E1-M1
# 9098@O1-M2_E2-M1
# 9098@O2-M1_E1-M1
# 9098@O2-M1_E2-M1
# Af8a@O1-M2_E1-M1
# Af8a@O1-M2_E2-M1
# Af8a@O2-M1_E1-M1
# Af8a@O2-M1_E2-M1
# AsLD@O1-M2_E1-M1
# AsLD@O1-M2_E2-M1
# AsLD@O2-M1_E1-M1
# AsLD@O2-M1_E2-M1
# Dr51@O1-M2_E1-M1
# Dr51@O1-M2_E2-M1
# Dr51@O2-M1_E1-M1
# Dr51@O2-M1_E2-M1
# DYYI@O1-M2_E1-M1
# DYYI@O1-M2_E2-M1
# DYYI@O2-M1_E1-M1
# DYYI@O2-M1_E2-M1
# fT68@O1-M2_E1-M1
# fT68@O1-M2_E2-M1
# fT68@O2-M1_E1-M1
# fT68@O2-M1_E2-M1
# MS6u@O1-M2_E1-M1
# MS6u@O1-M2_E2-M1
# MS6u@O2-M1_E1-M1
# MS6u@O2-M1_E2-M1
# Msy4@O1-M2_E1-M1
# Msy4@O1-M2_E2-M1
# Msy4@O2-M1_E1-M1
# Msy4@O2-M1_E2-M1
# SOZ3@O1-M2_E1-M1
# SOZ3@O1-M2_E2-M1
# SOZ3@O2-M1_E1-M1
# SOZ3@O2-M1_E2-M1
# Y4FK@O1-M2_E1-M1
# Y4FK@O1-M2_E2-M1
# Y4FK@O2-M1_E1-M1
# Y4FK@O2-M1_E2-M1
# YHLr@O1-M2_E1-M1
# YHLr@O1-M2_E2-M1
# YHLr@O2-M1_E1-M1
# YHLr@O2-M1_E2-M1

# %%
# pr curve for logistic regression model
from sklearn.metrics import precision_score, recall_score
 
# calculate pr-curve
thresholds = np.arange(start=0.025, stop=1.0, step=0.025)
precision = np.array([precision_score(valid_y, valid_probs>=t) for t in thresholds])
recall = np.array([recall_score(valid_y, valid_probs>=t) for t in thresholds])

# convert to f score
fscore = (2 * precision * recall) / (precision + recall)
# locate the index of the largest f score
opt_idx = np.argmax(fscore)

# plot the roc curve for the model
no_skill = len(valid_y[valid_y==1]) / len(valid_y)
_, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5))
ax1.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill', color="tab:orange")
ax1.plot(recall, precision, marker='.', label='mU-Sleep', color="tab:blue")
ax1.plot(recall[opt_idx], precision[opt_idx], marker="*", color="tab:green", markersize=12, label="Optimal", linestyle="none")
ax1.set_xlabel('Recall')
ax1.set_ylabel('Precision')
ax1.legend()
ax1.grid()
info_txt = f"Threshold={thresholds[opt_idx]:.2f}\nF1-Score={fscore[opt_idx]:.2f}" 
ty = -0.1
tx = -0.25
ax1.text(recall[opt_idx]+tx, precision[opt_idx]+ty, info_txt)

# Plot F1-threshold curve
ax2.plot(thresholds, fscore, marker='.', color="tab:blue")
ax2.plot(thresholds[opt_idx], fscore[opt_idx], marker='*', markersize=12, color="tab:green", label="Optimal")
ax2.set_ylim([0,1])
ax2.grid()
ax2.set_xlabel("Thresholds")
ax2.set_ylabel("F1-Score")

print('Best Threshold=%.3f, F-Score=%.3f, Recall=%.3f, Precision=%.3f' % (thresholds[opt_idx], fscore[opt_idx], recall[opt_idx], precision[opt_idx]))
# Out:
# Best Threshold=0.700, F-Score=0.786, Recall=0.830, Precision=0.747

# %% [markdown]
# ### Test predictions

# %%
# Make test predictions using average probabilites per subject across channel combinations using optimal index

# Collect data

test_data = {d.description['subject'].split("@")[0]: {"probs": [], "y": []} 
                for d in windows_dataset.datasets
                     if d.description['subject'].split("@")[0] in split_ids['test']}
 
for d in windows_dataset.datasets:
    id = d.description['subject'].split("@")[0]
 
    if id not in split_ids['test']:
        continue
 
    print(d.description['subject'])
    window_data = d.windows.get_data()
    features = emb(torch.Tensor(window_data)).detach().numpy()
    probs = clf_pipe.predict_proba(features)
    test_data[id]["probs"].append(probs)
    test_data[id]["y"] = d.y
 
for k, v in test_data.items():
    all_probs = np.array(v["probs"]).mean(axis=0)[:,1]
    test_data[k]["avg_probs"] = all_probs
 
from sklearn.metrics import cohen_kappa_score, f1_score
 
test_preds = np.concatenate([v["avg_probs"] for _, v in test_data.items()]) >= thresholds[opt_idx]
test_y = np.concatenate([v["y"] for _, v in test_data.items()]) > 0
 
print(f"Logistic regression Cohen's kappa (@ {thresholds[opt_idx]:.2f}) with averaged probabilites:")
print(cohen_kappa_score(test_y, test_preds))
 
print(f"Logistic regression F1 score (@ {thresholds[opt_idx]:.2f}) with averaged probabilites:")
print(f1_score(test_y, test_preds))
# Out:
# 0pai@O1-M2_E1-M1
# 0pai@O1-M2_E2-M1
# 0pai@O2-M1_E1-M1
# 0pai@O2-M1_E2-M1
# 3P0D@O1-M2_E1-M1
# 3P0D@O1-M2_E2-M1
# 3P0D@O2-M1_E1-M1
# 3P0D@O2-M1_E2-M1
# 40kO@O1-M2_E1-M1
# 40kO@O1-M2_E2-M1
# 40kO@O2-M1_E1-M1
# 40kO@O2-M1_E2-M1
# 6iwd@O1-M2_E1-M1
# 6iwd@O1-M2_E2-M1
# 6iwd@O2-M1_E1-M1
# 6iwd@O2-M1_E2-M1
# 6JVj@O1-M2_E1-M1
# 6JVj@O1-M2_E2-M1
# 6JVj@O2-M1_E1-M1
# 6JVj@O2-M1_E2-M1
# BSvO@O1-M2_E1-M1
# BSvO@O1-M2_E2-M1
# BSvO@O2-M1_E1-M1
# BSvO@O2-M1_E2-M1
# csxQ@O1-M2_E1-M1
# csxQ@O1-M2_E2-M1
# csxQ@O2-M1_E1-M1
# csxQ@O2-M1_E2-M1
# DSfb@O1-M2_E1-M1
# DSfb@O1-M2_E2-M1
# DSfb@O2-M1_E1-M1
# DSfb@O2-M1_E2-M1
# EyTS@O1-M2_E1-M1
# EyTS@O1-M2_E2-M1
# EyTS@O2-M1_E1-M1
# EyTS@O2-M1_E2-M1
# hcml@O1-M2_E1-M1
# hcml@O1-M2_E2-M1
# hcml@O2-M1_E1-M1
# hcml@O2-M1_E2-M1
# hRMy@O1-M2_E1-M1
# hRMy@O1-M2_E2-M1
# hRMy@O2-M1_E1-M1
# hRMy@O2-M1_E2-M1
# ibbz@O1-M2_E1-M1
# ibbz@O1-M2_E2-M1
# ibbz@O2-M1_E1-M1
# ibbz@O2-M1_E2-M1
# IhpU@O1-M2_E1-M1
# IhpU@O1-M2_E2-M1
# IhpU@O2-M1_E1-M1
# IhpU@O2-M1_E2-M1
# kj2l@O1-M2_E1-M1
# kj2l@O1-M2_E2-M1
# kj2l@O2-M1_E1-M1
# kj2l@O2-M1_E2-M1
# Kn9O@O1-M2_E1-M1
# Kn9O@O1-M2_E2-M1
# Kn9O@O2-M1_E1-M1
# Kn9O@O2-M1_E2-M1
# mBks@O1-M2_E1-M1
# mBks@O1-M2_E2-M1
# mBks@O2-M1_E1-M1
# mBks@O2-M1_E2-M1
# mZje@O1-M2_E1-M1
# mZje@O1-M2_E2-M1
# mZje@O2-M1_E1-M1
# mZje@O2-M1_E2-M1
# N1nM@O1-M2_E1-M1
# N1nM@O1-M2_E2-M1
# N1nM@O2-M1_E1-M1
# N1nM@O2-M1_E2-M1
# Otq3@O1-M2_E1-M1
# Otq3@O1-M2_E2-M1
# Otq3@O2-M1_E1-M1
# Otq3@O2-M1_E2-M1
# R2f3@O1-M2_E1-M1
# R2f3@O1-M2_E2-M1
# R2f3@O2-M1_E1-M1
# R2f3@O2-M1_E2-M1
# tG6i@O1-M2_E1-M1
# tG6i@O1-M2_E2-M1
# tG6i@O2-M1_E1-M1
# tG6i@O2-M1_E2-M1
# Xg1l@O1-M2_E1-M1
# Xg1l@O1-M2_E2-M1
# Xg1l@O2-M1_E1-M1
# Xg1l@O2-M1_E2-M1
# Xii6@O1-M2_E1-M1
# Xii6@O1-M2_E2-M1
# Xii6@O2-M1_E1-M1
# Xii6@O2-M1_E2-M1
# Logistic regression Cohen's kappa (@ 0.70) with averaged probabilites:
# 0.6593190353218246
# Logistic regression F1 score (@ 0.70) with averaged probabilites:
# 0.6895796847635727

# %% [markdown]
# ### Plotting feature space (PCA)

# %%
# Feature space PCA plot

# get_ipython().run_line_magic('matplotlib', 'widget')
from sklearn.decomposition import PCA
from matplotlib import cm
 
X = np.concatenate([v[0] for k, v in data.items()])
y = np.concatenate([v[1] for k, v in data.items()])
y[y!=1] = 0
 
n = 2
 
pca = PCA(n_components=n)
#tsne = TSNE(n_components=n)
components = pca.fit_transform(X)
 
stages = ["W","MS"]
if n != 3:
    fig, ax = plt.subplots()
    colors = cm.get_cmap('viridis', 2)(range(2))
    for i, stage in enumerate(stages):
        mask = y == i
        ax.scatter(components[mask, 0], components[mask, 1], s=3, alpha=0.7,
                   color=colors[i], label=stage)
else:
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    colors = cm.get_cmap('viridis', 2)(range(2))
    for i, stage in enumerate(stages):
        mask = y == i
        ax.scatter(components[mask, 0], components[mask, 1], components[mask, 2],
                   s=1, alpha=0.7, color=colors[i], label=stage)
 
ax.legend()
plt.show()

# %% [markdown]
# ## Collect all data to export to matlab for analysis

# %% [markdown]
# ### Training data

# %%
train_data = {d.description['subject'].split("@")[0]: {"probs": [], "y": []} 
                for d in windows_dataset.datasets
                     if d.description['subject'].split("@")[0] in split_ids['train']}
 
for d in windows_dataset.datasets:
    id = d.description['subject'].split("@")[0]
 
    if id not in split_ids['train']:
        continue
 
    print(d.description['subject'])
    window_data = d.windows.get_data()
    features = emb(torch.Tensor(window_data)).detach().numpy()
    probs = clf_pipe.predict_proba(features)
    train_data[id]["probs"].append(probs)
    train_data[id]["y"] = d.y
 
for k, v in train_data.items():
    all_probs = np.array(v["probs"]).mean(axis=0)[:,1]
    train_data[k]["avg_probs"] = all_probs
# Out:
# 0ncr@O1-M2_E1-M1
# 0ncr@O1-M2_E2-M1
# 0ncr@O2-M1_E1-M1
# 0ncr@O2-M1_E2-M1
# 3J4W@O1-M2_E1-M1
# 3J4W@O1-M2_E2-M1
# 3J4W@O2-M1_E1-M1
# 3J4W@O2-M1_E2-M1
# 5bSg@O1-M2_E1-M1
# 5bSg@O1-M2_E2-M1
# 5bSg@O2-M1_E1-M1
# 5bSg@O2-M1_E2-M1
# 9JQY@O1-M2_E1-M1
# 9JQY@O1-M2_E2-M1
# 9JQY@O2-M1_E1-M1
# 9JQY@O2-M1_E2-M1
# AXbm@O1-M2_E1-M1
# AXbm@O1-M2_E2-M1
# AXbm@O2-M1_E1-M1
# AXbm@O2-M1_E2-M1
# bkx9@O1-M2_E1-M1
# bkx9@O1-M2_E2-M1
# bkx9@O2-M1_E1-M1
# bkx9@O2-M1_E2-M1
# C1Wu@O1-M2_E1-M1
# C1Wu@O1-M2_E2-M1
# C1Wu@O2-M1_E1-M1
# C1Wu@O2-M1_E2-M1
# cblr@O1-M2_E1-M1
# cblr@O1-M2_E2-M1
# cblr@O2-M1_E1-M1
# cblr@O2-M1_E2-M1
# d3ET@O1-M2_E1-M1
# d3ET@O1-M2_E2-M1
# d3ET@O2-M1_E1-M1
# d3ET@O2-M1_E2-M1
# ddTG@O1-M2_E1-M1
# ddTG@O1-M2_E2-M1
# ddTG@O2-M1_E1-M1
# ddTG@O2-M1_E2-M1
# DjrT@O1-M2_E1-M1
# DjrT@O1-M2_E2-M1
# DjrT@O2-M1_E1-M1
# DjrT@O2-M1_E2-M1
# EHED@O1-M2_E1-M1
# EHED@O1-M2_E2-M1
# EHED@O2-M1_E1-M1
# EHED@O2-M1_E2-M1
# EMcQ@O1-M2_E1-M1
# EMcQ@O1-M2_E2-M1
# EMcQ@O2-M1_E1-M1
# EMcQ@O2-M1_E2-M1
# f8H5@O1-M2_E1-M1
# f8H5@O1-M2_E2-M1
# f8H5@O2-M1_E1-M1
# f8H5@O2-M1_E2-M1
# fNe4@O1-M2_E1-M1
# fNe4@O1-M2_E2-M1
# fNe4@O2-M1_E1-M1
# fNe4@O2-M1_E2-M1
# G7PJ@O1-M2_E1-M1
# G7PJ@O1-M2_E2-M1
# G7PJ@O2-M1_E1-M1
# G7PJ@O2-M1_E2-M1
# go56@O1-M2_E1-M1
# go56@O1-M2_E2-M1
# go56@O2-M1_E1-M1
# go56@O2-M1_E2-M1
# hT38@O1-M2_E1-M1
# hT38@O1-M2_E2-M1
# hT38@O2-M1_E1-M1
# hT38@O2-M1_E2-M1
# ipxV@O1-M2_E1-M1
# ipxV@O1-M2_E2-M1
# ipxV@O2-M1_E1-M1
# ipxV@O2-M1_E2-M1
# iSqw@O1-M2_E1-M1
# iSqw@O1-M2_E2-M1
# iSqw@O2-M1_E1-M1
# iSqw@O2-M1_E2-M1
# Ivfn@O1-M2_E1-M1
# Ivfn@O1-M2_E2-M1
# Ivfn@O2-M1_E1-M1
# Ivfn@O2-M1_E2-M1
# JCpz@O1-M2_E1-M1
# JCpz@O1-M2_E2-M1
# JCpz@O2-M1_E1-M1
# JCpz@O2-M1_E2-M1
# LR2s@O1-M2_E1-M1
# LR2s@O1-M2_E2-M1
# LR2s@O2-M1_E1-M1
# LR2s@O2-M1_E2-M1
# muls@O1-M2_E1-M1
# muls@O1-M2_E2-M1
# muls@O2-M1_E1-M1
# muls@O2-M1_E2-M1
# Nzhl@O1-M2_E1-M1
# Nzhl@O1-M2_E2-M1
# Nzhl@O2-M1_E1-M1
# Nzhl@O2-M1_E2-M1
# oOMR@O1-M2_E1-M1
# oOMR@O1-M2_E2-M1
# oOMR@O2-M1_E1-M1
# oOMR@O2-M1_E2-M1
# pPpj@O1-M2_E1-M1
# pPpj@O1-M2_E2-M1
# pPpj@O2-M1_E1-M1
# pPpj@O2-M1_E2-M1
# puoa@O1-M2_E1-M1
# puoa@O1-M2_E2-M1
# puoa@O2-M1_E1-M1
# puoa@O2-M1_E2-M1
# QDsa@O1-M2_E1-M1
# QDsa@O1-M2_E2-M1
# QDsa@O2-M1_E1-M1
# QDsa@O2-M1_E2-M1
# RfL0@O1-M2_E1-M1
# RfL0@O1-M2_E2-M1
# RfL0@O2-M1_E1-M1
# RfL0@O2-M1_E2-M1
# RM1S@O1-M2_E1-M1
# RM1S@O1-M2_E2-M1
# RM1S@O2-M1_E1-M1
# RM1S@O2-M1_E2-M1
# sNMf@O1-M2_E1-M1
# sNMf@O1-M2_E2-M1
# sNMf@O2-M1_E1-M1
# sNMf@O2-M1_E2-M1
# svlu@O1-M2_E1-M1
# svlu@O1-M2_E2-M1
# svlu@O2-M1_E1-M1
# svlu@O2-M1_E2-M1
# UsSz@O1-M2_E1-M1
# UsSz@O1-M2_E2-M1
# UsSz@O2-M1_E1-M1
# UsSz@O2-M1_E2-M1
# UwK6@O1-M2_E1-M1
# UwK6@O1-M2_E2-M1
# UwK6@O2-M1_E1-M1
# UwK6@O2-M1_E2-M1
# uXdB@O1-M2_E1-M1
# uXdB@O1-M2_E2-M1
# uXdB@O2-M1_E1-M1
# uXdB@O2-M1_E2-M1
# X7s0@O1-M2_E1-M1
# X7s0@O1-M2_E2-M1
# X7s0@O2-M1_E1-M1
# X7s0@O2-M1_E2-M1
# y5We@O1-M2_E1-M1
# y5We@O1-M2_E2-M1
# y5We@O2-M1_E1-M1
# y5We@O2-M1_E2-M1
# YOh8@O1-M2_E1-M1
# YOh8@O1-M2_E2-M1
# YOh8@O2-M1_E1-M1
# YOh8@O2-M1_E2-M1
# zaca@O1-M2_E1-M1
# zaca@O1-M2_E2-M1
# zaca@O2-M1_E1-M1
# zaca@O2-M1_E2-M1
# Zpwh@O1-M2_E1-M1
# Zpwh@O1-M2_E2-M1
# Zpwh@O2-M1_E1-M1
# Zpwh@O2-M1_E2-M1
# ZYFG@O1-M2_E1-M1
# ZYFG@O1-M2_E2-M1
# ZYFG@O2-M1_E1-M1
# ZYFG@O2-M1_E2-M1

# %% [markdown]
# ### Collect validation and trian data as dev data

# %%
from scipy.io import savemat

dev_id = []
dev_probs = []
dev_true = []

for k, v in val_data.items():
    dev_id.append(k)
    dev_probs.append(v["avg_probs"])
    dev_true.append(v['y'])

for k, v in train_data.items():
    dev_id.append(k)
    dev_probs.append(v["avg_probs"])
    dev_true.append(v['y'])

dev_out = {"id": dev_id, 
           "probs": dev_probs,
           "yTrue": dev_true,
           "optThres": thresholds[opt_idx]}

savemat("Matlab/training_performance/ssl.mat", mdict = dev_out)
# Out:
# c:\Users\Sindri\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:493: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   narr = np.asanyarray(source)

# %% [markdown]
# ### Test data

# %%
test_id = []
test_probs = []
test_true = []

for k, v in test_data.items():
    test_id.append(k)
    test_probs.append(v["avg_probs"])
    test_true.append(v['y'])

test_out = {"id": test_id, 
           "probs": test_probs,
           "yTrue": test_true,
           "optThres": thresholds[opt_idx]}

savemat("Matlab/ssl.mat", mdict = test_out)
